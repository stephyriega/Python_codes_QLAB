# %% [markdown]
# ### Import the data located at this link. It has information on people infected with dengue at the district level for 2015 to 2021.

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: fiona>=1.8 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from geopandas) (1.9.2)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: packaging in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from geopandas) (22.0)
# Requirement already satisfied: shapely>=1.7 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: click~=8.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: certifi in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.23.5)
# Requirement already satisfied: colorama in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8->geopandas) (0.4.6)
# Requirement already satisfied: six in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt 
import chardet
from geopandas import GeoDataFrame

# %%
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Point, LineString
import folium 
from folium import Marker, GeoJson
from folium.plugins import MarkerCluster, HeatMap

# %%
pwd
# Out:
# 'C:\\Users\\sriega\\Documents\\GitHub\\Python_codes_QLAB\\Intermediate'

# %%
#Import the data
link = "https://raw.githubusercontent.com/alexanderquispe/Diplomado_PUCP/main/_data/data_dengue_peru.csv"
data = pd.read_csv(link)
data.head(3)
# Out:
# C:\Users\sriega\AppData\Local\Temp\ipykernel_14928\3529399732.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(link)
#     Año  Semana Eventos o daños Departamento   Distrito       Provincia  \
# 0  2020      43          Dengue        CUSCO  MEGANTONI   LA CONVENCION
# 1  2021      41          Dengue     MOQUEGUA   MOQUEGUA  MARISCAL NIETO
# 2  2021      42          Dengue     MOQUEGUA   MOQUEGUA  MARISCAL NIETO
#
#    Ubigeo Casos
# 0   80914   2.0
# 1  180101   NaN
# 2  180101   NaN

# %%
#Replace Null values with 0 in order to change the type value from 'Casos'
data['Casos'] = data['Casos'].fillna(0)
data
# Out:
#          Año  Semana Eventos o daños   Departamento       Distrito  \
# 0       2020      43          Dengue          CUSCO      MEGANTONI
# 1       2021      41          Dengue       MOQUEGUA       MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA       MOQUEGUA
# 3       2020       1          Dengue          CUSCO      MEGANTONI
# 4       2020      53          Dengue          CUSCO      MEGANTONI
# ...      ...     ...             ...            ...            ...
# 172139  2021      49          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS      TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS  MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS      TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS      TAHUAMANU
#
#              Provincia  Ubigeo Casos
# 0        LA CONVENCION   80914   2.0
# 1       MARISCAL NIETO  180101     0
# 2       MARISCAL NIETO  180101     0
# 3        LA CONVENCION   80914   0.0
# 4        LA CONVENCION   80914   2.0
# ...                ...     ...   ...
# 172139            MANU  170203     0
# 172140       TAHUAMANU  170303     0
# 172141            MANU  170203     0
# 172142       TAHUAMANU  170303     0
# 172143       TAHUAMANU  170303     0
#
# [172144 rows x 8 columns]

# %%
#Check type value
data.dtypes
# Out:
# Año                 int64
# Semana              int64
# Eventos o daños    object
# Departamento       object
# Distrito           object
# Provincia          object
# Ubigeo              int64
# Casos              object
# dtype: object

# %%
#Change the type value from 'Casos'
data['Casos'] = data['Casos'].str.replace(',','').astype(float)

# %%
data.dtypes
# Out:
# Año                  int64
# Semana               int64
# Eventos o daños     object
# Departamento        object
# Distrito            object
# Provincia           object
# Ubigeo               int64
# Casos              float64
# dtype: object

# %%
#Eliminate the unnecesary columns
data2= data[["Año", "Departamento", "Distrito", "Provincia", "Ubigeo", "Casos"]]
data2
# Out:
#          Año   Departamento       Distrito       Provincia  Ubigeo  Casos
# 0       2020          CUSCO      MEGANTONI   LA CONVENCION   80914    NaN
# 1       2021       MOQUEGUA       MOQUEGUA  MARISCAL NIETO  180101    NaN
# 2       2021       MOQUEGUA       MOQUEGUA  MARISCAL NIETO  180101    NaN
# 3       2020          CUSCO      MEGANTONI   LA CONVENCION   80914    NaN
# 4       2020          CUSCO      MEGANTONI   LA CONVENCION   80914    NaN
# ...      ...            ...            ...             ...     ...    ...
# 172139  2021  MADRE DE DIOS  MADRE DE DIOS            MANU  170203    NaN
# 172140  2021  MADRE DE DIOS      TAHUAMANU       TAHUAMANU  170303    NaN
# 172141  2021  MADRE DE DIOS  MADRE DE DIOS            MANU  170203    NaN
# 172142  2021  MADRE DE DIOS      TAHUAMANU       TAHUAMANU  170303    NaN
# 172143  2021  MADRE DE DIOS      TAHUAMANU       TAHUAMANU  170303    NaN
#
# [172144 rows x 6 columns]

# %%
data2["Distrito"].unique().size
# Out:
# 455

# %%
#Group by the previous dataframe
data_2 = data2.groupby( ['Año', 'Departamento', 'Provincia', 'Distrito', 'Ubigeo' ], as_index = False )[['Casos']].sum()
data_2
# Out:
#        Año Departamento   Provincia    Distrito  Ubigeo  Casos
# 0     2015     AMAZONAS       BAGUA    ARAMANGO   10202    0.0
# 1     2015     AMAZONAS       BAGUA       BAGUA   10201    7.0
# 2     2015     AMAZONAS       BAGUA    COPALLIN   10203    0.0
# 3     2015     AMAZONAS       BAGUA    EL PARCO   10204    0.0
# 4     2015     AMAZONAS       BAGUA       IMAZA   10205    1.0
# ...    ...          ...         ...         ...     ...    ...
# 3243  2021      UCAYALI  PADRE ABAD    CURIMANA  250303   22.0
# 3244  2021      UCAYALI  PADRE ABAD     IRAZOLA  250302   19.0
# 3245  2021      UCAYALI  PADRE ABAD     NESHUYA  250304   11.0
# 3246  2021      UCAYALI  PADRE ABAD  PADRE ABAD  250301   68.0
# 3247  2021      UCAYALI       PURUS       PURUS  250401    0.0
#
# [3248 rows x 6 columns]

# %%
data_2["Distrito"].unique().size
# Out:
# 455

# %%
#df = data.groupby(['Año','Ubigeo', 'Departamento', 'Provincia', 'Distrito'])['Casos'].agg('sum')

# %% [markdown]
# #### Generate ubigeo for Departments and Provinces taking the first two and four numbers. Hint: Use this code.

# %%
data.dtypes
# Out:
# Año                  int64
# Semana               int64
# Eventos o daños     object
# Departamento        object
# Distrito            object
# Provincia           object
# Ubigeo               int64
# Casos              float64
# dtype: object

# %%
#Create a special UBIGEO for Departments
data_2['UBIGEO_DEP'] = data_2['Ubigeo'].astype(str).str[0:2]
#Create a special UBIGEO for Provinces
data_2['UBIGEO_PRO'] = data_2['Ubigeo'].astype(str).str[0:4]
data_2
# Out:
#        Año Departamento   Provincia    Distrito  Ubigeo  Casos UBIGEO_DEP  \
# 0     2015     AMAZONAS       BAGUA    ARAMANGO   10202    0.0         10
# 1     2015     AMAZONAS       BAGUA       BAGUA   10201    7.0         10
# 2     2015     AMAZONAS       BAGUA    COPALLIN   10203    0.0         10
# 3     2015     AMAZONAS       BAGUA    EL PARCO   10204    0.0         10
# 4     2015     AMAZONAS       BAGUA       IMAZA   10205    1.0         10
# ...    ...          ...         ...         ...     ...    ...        ...
# 3243  2021      UCAYALI  PADRE ABAD    CURIMANA  250303   22.0         25
# 3244  2021      UCAYALI  PADRE ABAD     IRAZOLA  250302   19.0         25
# 3245  2021      UCAYALI  PADRE ABAD     NESHUYA  250304   11.0         25
# 3246  2021      UCAYALI  PADRE ABAD  PADRE ABAD  250301   68.0         25
# 3247  2021      UCAYALI       PURUS       PURUS  250401    0.0         25
#
#      UBIGEO_PRO
# 0          1020
# 1          1020
# 2          1020
# 3          1020
# 4          1020
# ...         ...
# 3243       2503
# 3244       2503
# 3245       2503
# 3246       2503
# 3247       2504
#
# [3248 rows x 8 columns]

# %% [markdown]
# #### Use geopandas to plot the number of cases in 2021 by the district using a continuous legend. Do not forget to indicate the color of NA values. Use this shapefile.

# %%
#Import Shapefile
maps1 = gpd.read_file(r'../_data/LIMITE_DISTRITAL_2020_INEI/INEI_LIMITE_DISTRITAL.shp')
maps1["geometry"][0]
# Out:
# <POLYGON ((-78.916 -7.321, -78.914 -7.322, -78.913 -7.323, -78.911 -7.324, -...>

# %%
maps1[0:5]
# Out:
#   CCDD    NOMBDEP CCPP    NOMBPROV CCDI      NOMBDIST          CAPITAL  \
# 0   06  CAJAMARCA   05   CONTUMAZA   04      GUZMANGO         GUZMANGO
# 1   06  CAJAMARCA   11  SAN MIGUEL   05      EL PRADO         EL PRADO
# 2   06  CAJAMARCA   11  SAN MIGUEL   09        NIEPOS           NIEPOS
# 3   06  CAJAMARCA   11  SAN MIGUEL   10  SAN GREGORIO     SAN GREGORIO
# 4   06  CAJAMARCA   12   SAN PABLO   03      SAN LUIS  SAN LUIS GRANDE
#
#    UBIGEO IDPROV  CODIGO  CNT_CCPP    DESCRIPCIO           DESCARGAR  \
# 0  060504   0605  060504        50      GUZMANGO  www.geogpsperu.com
# 1  061105   0611  061105        15      EL PRADO  www.geogpsperu.com
# 2  061109   0611  061109        41        NIEPOS  www.geogpsperu.com
# 3  061110   0611  061110        48  SAN GREGORIO  www.geogpsperu.com
# 4  061203   0612  061203         9      SAN LUIS  www.geogpsperu.com
#
#     WHATSAPP                  CONTACTO  \
# 0  931381206  juan.suyo@geogpsperu.com
# 1  931381206  juan.suyo@geogpsperu.com
# 2  931381206  juan.suyo@geogpsperu.com
# 3  931381206  juan.suyo@geogpsperu.com
# 4  931381206  juan.suyo@geogpsperu.com
#
#                                             geometry
# 0  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...

# %%
#Check unique values (from identifiers for the districts)

maps1['UBIGEO'].is_unique #It's true

maps1['UBIGEO'].unique().size
# Out:
# 1874

# %%
#We filter the Shape file by UBIGEO and geometry
maps = maps1[['UBIGEO', 'geometry']]
maps = maps.rename({'UBIGEO':'Ubigeo'}, axis =1 )
maps
# Out:
#       Ubigeo                                           geometry
# 0     060504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1     061105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2     061109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3     061110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4     061203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...
# ...      ...                                                ...
# 1869  040404  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...
# 1870  040405  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...
# 1871  040406  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...
# 1872  040407  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...
# 1873  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...
#
# [1874 rows x 2 columns]

# %%
#We analyze if UBIGEO is a int value or not
maps.dtypes
# Out:
# Ubigeo        object
# geometry    geometry
# dtype: object

# %%
# First change from Object to string, after that, to int

maps['Ubigeo'] = maps['Ubigeo'].astype(str).astype(int)
maps
# Out:
#       Ubigeo                                           geometry
# 0      60504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1      61105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2      61109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3      61110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4      61203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...
# ...      ...                                                ...
# 1869   40404  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...
# 1870   40405  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...
# 1871   40406  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...
# 1872   40407  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...
# 1873  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...
#
# [1874 rows x 2 columns]

# %%
# Analyze which longitud-latitud projection is
maps.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Merge using inner way to drop missing values 

dataset = maps.merge(data_2, on="Ubigeo", how="outer", indicator= True)
dataset
# Out:
#       Ubigeo                                           geometry     Año  \
# 0      60504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...     NaN
# 1      61105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...     NaN
# 2      61109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...     NaN
# 3      61110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...     NaN
# 4      61203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...     NaN
# ...      ...                                                ...     ...
# 4642  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2017.0
# 4643  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2018.0
# 4644  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2019.0
# 4645  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2020.0
# 4646  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2021.0
#
#      Departamento Provincia  Distrito  Casos UBIGEO_DEP UBIGEO_PRO     _merge
# 0             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 1             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 2             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 3             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 4             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# ...           ...       ...       ...    ...        ...        ...        ...
# 4642        JUNIN    SATIPO  MAZAMARI    7.0         12       1206       both
# 4643        JUNIN    SATIPO  MAZAMARI    0.0         12       1206       both
# 4644        JUNIN    SATIPO  MAZAMARI    0.0         12       1206       both
# 4645        JUNIN    SATIPO  MAZAMARI    0.0         12       1206       both
# 4646        JUNIN    SATIPO  MAZAMARI  105.0         12       1206       both
#
# [4647 rows x 10 columns]

# %%
dataset["Ubigeo"].unique().size
# Out:
# 1874

# %%
# Function to filter dataset_dengue by year and administrative space(province)

def subdata( a, b):
    
    if b == "All-Peru":
        
        resultado = dataset.loc[(dataset['Año']== a) | (dataset['Año'].isnull()) ]
    else:
        resultado = dataset.loc[ ( (dataset['Año']== a) | (dataset['Año'].isnull()) ) & (dataset['Provincia']== b)]
    return resultado  

#2 arguments: Year and Location

# %%
#Select one criteria: All Peru 2021

dataset_2021 = subdata( 2021 , "All-Peru")
dataset_2021
# Out:
#       Ubigeo                                           geometry     Año  \
# 0      60504  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...     NaN
# 1      61105  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...     NaN
# 2      61109  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...     NaN
# 3      61110  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...     NaN
# 4      61203  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...     NaN
# ...      ...                                                ...     ...
# 4636   40404  POLYGON ((-71.95148 -14.83836, -71.95157 -14.8...     NaN
# 4637   40405  POLYGON ((-72.37490 -15.24990, -72.37494 -15.2...     NaN
# 4638   40406  POLYGON ((-71.96976 -15.13597, -71.96952 -15.1...     NaN
# 4639   40407  POLYGON ((-72.31258 -15.81426, -72.31211 -15.8...     NaN
# 4646  120604  POLYGON ((-73.98589 -11.93382, -73.98628 -11.9...  2021.0
#
#      Departamento Provincia  Distrito  Casos UBIGEO_DEP UBIGEO_PRO     _merge
# 0             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 1             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 2             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 3             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 4             NaN       NaN       NaN    NaN        NaN        NaN  left_only
# ...           ...       ...       ...    ...        ...        ...        ...
# 4636          NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 4637          NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 4638          NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 4639          NaN       NaN       NaN    NaN        NaN        NaN  left_only
# 4646        JUNIN    SATIPO  MAZAMARI  105.0         12       1206       both
#
# [1868 rows x 10 columns]

# %%
dataset_2021["Ubigeo"].unique().size
# Out:
# 1868

# %%
dataset_2021["_merge"].unique()
# Out:
# ['left_only', 'both']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
dataset_2021.dtypes
# Out:
# Ubigeo             int32
# geometry        geometry
# Año              float64
# Departamento      object
# Provincia         object
# Distrito          object
# Casos            float64
# UBIGEO_DEP        object
# UBIGEO_PRO        object
# _merge          category
# dtype: object

# %%
#Plot this first graph in order to use the argument 'cmap'. We plot the DataFrame with NaN values. We use a continuous legend.
fig, ax = plt.subplots(figsize=(20, 20))

cmap = plt.cm.get_cmap('Blues')

cmap.set_bad(color='black')

dataset_2021.plot(column='Casos', cmap=cmap,
                   ax=ax, edgecolor='black',
                   legend=True, missing_kwds={'color': 'grey'})
# Out:
# C:\Users\sriega\AppData\Local\Temp\ipykernel_14928\1402464802.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues')
# <Axes: >

# %%
# Inverting colour map
cmap = plt.cm.OrRd

# %%
# !pip install mapclassify
# Out:
# Requirement already satisfied: mapclassify in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: scikit-learn in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.2.1)
# Requirement already satisfied: numpy>=1.3 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.23.5)
# Requirement already satisfied: pandas>=1.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.5.3)
# Requirement already satisfied: networkx in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from mapclassify) (2.8.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.10.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from pandas>=1.0->mapclassify) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from pandas>=1.0->mapclassify) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from scikit-learn->mapclassify) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from scikit-learn->mapclassify) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0->mapclassify) (1.16.0)

# %%
#Final graph for this 3rd question. We use a discrete legend.
fig, ax = plt.subplots(figsize=(20, 20))

cmap = plt.cm.get_cmap('Blues')

cmap.set_bad(color='black')

dataset_2021.plot( ax = ax, 
        column='Casos', 
         cmap= cmap, 
        figsize=(20, 20), 
         linestyle='--',
         edgecolor='black', 
         legend = True,  
         scheme = "User_Defined", 
         classification_kwds = dict( bins = [ 50, 100, 200, 250,  500 ] ), 
         legend_kwds=dict(  loc='upper left',
                            bbox_to_anchor=(1.01, 1),
                            fontsize='x-large',
                            title= "Dengue Cases by Districts", 
                            title_fontsize = 'x-large', 
                            frameon= False ),
         missing_kwds={'color': 'grey'}
        )
# Out:
# C:\Users\sriega\AppData\Local\Temp\ipykernel_14928\1653033055.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues')
# <Axes: >

# %% [markdown]
# #### Use geopandas to plot the number of cases in 2021by the province using a continuous legend. Do not forget to indicate the color of NA values. Use this shapefile.

# %%
maps1.head(5) #is a district level
# Out:
#   CCDD    NOMBDEP CCPP    NOMBPROV CCDI      NOMBDIST          CAPITAL  \
# 0   06  CAJAMARCA   05   CONTUMAZA   04      GUZMANGO         GUZMANGO
# 1   06  CAJAMARCA   11  SAN MIGUEL   05      EL PRADO         EL PRADO
# 2   06  CAJAMARCA   11  SAN MIGUEL   09        NIEPOS           NIEPOS
# 3   06  CAJAMARCA   11  SAN MIGUEL   10  SAN GREGORIO     SAN GREGORIO
# 4   06  CAJAMARCA   12   SAN PABLO   03      SAN LUIS  SAN LUIS GRANDE
#
#    UBIGEO IDPROV  CODIGO  CNT_CCPP    DESCRIPCIO           DESCARGAR  \
# 0  060504   0605  060504        50      GUZMANGO  www.geogpsperu.com
# 1  061105   0611  061105        15      EL PRADO  www.geogpsperu.com
# 2  061109   0611  061109        41        NIEPOS  www.geogpsperu.com
# 3  061110   0611  061110        48  SAN GREGORIO  www.geogpsperu.com
# 4  061203   0612  061203         9      SAN LUIS  www.geogpsperu.com
#
#     WHATSAPP                  CONTACTO  \
# 0  931381206  juan.suyo@geogpsperu.com
# 1  931381206  juan.suyo@geogpsperu.com
# 2  931381206  juan.suyo@geogpsperu.com
# 3  931381206  juan.suyo@geogpsperu.com
# 4  931381206  juan.suyo@geogpsperu.com
#
#                                             geometry
# 0  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...

# %%
maps1['IDPROV'].unique().size
# Out:
# 196

# %%
prov_shp = maps1.dissolve( by = 'IDPROV' )
prov_shp = prov_shp.drop(columns=['UBIGEO','NOMBDIST'])
prov_shp.head(5)
# Out:
#                                                  geometry CCDD   NOMBDEP CCPP  \
# IDPROV
# 0101    POLYGON ((-77.78428 -6.94651, -77.78553 -6.948...   01  AMAZONAS   01
# 0102    POLYGON ((-78.32620 -5.56382, -78.32625 -5.565...   01  AMAZONAS   02
# 0103    POLYGON ((-77.93780 -6.03777, -77.93781 -6.037...   01  AMAZONAS   03
# 0104    POLYGON ((-77.58527 -4.47289, -77.58594 -4.475...   01  AMAZONAS   04
# 0105    POLYGON ((-77.93702 -6.69093, -77.93914 -6.693...   01  AMAZONAS   05
#
#             NOMBPROV CCDI                 CAPITAL  CODIGO  CNT_CCPP  \
# IDPROV
# 0101     CHACHAPOYAS   06             CHUQUIBAMBA  010106        39
# 0102           BAGUA   04                EL PARCO  010204         9
# 0103         BONGARA   11      VALERA (SAN PABLO)  010311        16
# 0104    CONDORCANQUI   01    SANTA MARIA DE NIEVA  010401       131
# 0105            LUYA   17  SAN FRANCISCO DEL YESO  010517        22
#
#                     DESCRIPCIO           DESCARGAR   WHATSAPP  \
# IDPROV
# 0101               CHUQUIBAMBA  www.geogpsperu.com  931381206
# 0102                  EL PARCO  www.geogpsperu.com  931381206
# 0103                    VALERA  www.geogpsperu.com  931381206
# 0104                     NIEVA  www.geogpsperu.com  931381206
# 0105    SAN FRANCISCO DEL YESO  www.geogpsperu.com  931381206
#
#                         CONTACTO
# IDPROV
# 0101    juan.suyo@geogpsperu.com
# 0102    juan.suyo@geogpsperu.com
# 0103    juan.suyo@geogpsperu.com
# 0104    juan.suyo@geogpsperu.com
# 0105    juan.suyo@geogpsperu.com

# %%
dataset_3 = data_2.groupby( ['Departamento', 'Provincia', 'UBIGEO_DEP','UBIGEO_PRO', "Año"], as_index = False).agg(Total_casos=('Casos', 'sum'))
dataset_3 = dataset_3.rename(columns={'UBIGEO_PRO':'IDPROV'})
dataset_3
# Out:
#     Departamento Provincia UBIGEO_DEP IDPROV   Año  Total_casos
# 0       AMAZONAS     BAGUA         10   1020  2015          8.0
# 1       AMAZONAS     BAGUA         10   1020  2016         21.0
# 2       AMAZONAS     BAGUA         10   1020  2017         56.0
# 3       AMAZONAS     BAGUA         10   1020  2018          0.0
# 4       AMAZONAS     BAGUA         10   1020  2019        127.0
# ..           ...       ...        ...    ...   ...          ...
# 667      UCAYALI     PURUS         25   2504  2015          0.0
# 668      UCAYALI     PURUS         25   2504  2016          0.0
# 669      UCAYALI     PURUS         25   2504  2017          0.0
# 670      UCAYALI     PURUS         25   2504  2020          0.0
# 671      UCAYALI     PURUS         25   2504  2021          0.0
#
# [672 rows x 6 columns]

# %%
dataset = pd.merge(prov_shp, dataset_3, how='left', on=['IDPROV'])
dataset
# Out:
#     IDPROV                                           geometry CCDD   NOMBDEP  \
# 0     0101  POLYGON ((-77.78428 -6.94651, -77.78553 -6.948...   01  AMAZONAS
# 1     0102  POLYGON ((-78.32620 -5.56382, -78.32625 -5.565...   01  AMAZONAS
# 2     0103  POLYGON ((-77.93780 -6.03777, -77.93781 -6.037...   01  AMAZONAS
# 3     0104  POLYGON ((-77.58527 -4.47289, -77.58594 -4.475...   01  AMAZONAS
# 4     0105  POLYGON ((-77.93702 -6.69093, -77.93914 -6.693...   01  AMAZONAS
# ..     ...                                                ...  ...       ...
# 594   2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
# 595   2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
# 596   2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
# 597   2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
# 598   2504  POLYGON ((-70.61380 -9.87339, -70.62140 -9.878...   25   UCAYALI
#
#     CCPP      NOMBPROV CCDI                 CAPITAL  CODIGO  CNT_CCPP  \
# 0     01   CHACHAPOYAS   06             CHUQUIBAMBA  010106        39
# 1     02         BAGUA   04                EL PARCO  010204         9
# 2     03       BONGARA   11      VALERA (SAN PABLO)  010311        16
# 3     04  CONDORCANQUI   01    SANTA MARIA DE NIEVA  010401       131
# 4     05          LUYA   17  SAN FRANCISCO DEL YESO  010517        22
# ..   ...           ...  ...                     ...     ...       ...
# 594   04         PURUS   01                   PURUS  250401        49
# 595   04         PURUS   01                   PURUS  250401        49
# 596   04         PURUS   01                   PURUS  250401        49
# 597   04         PURUS   01                   PURUS  250401        49
# 598   04         PURUS   01                   PURUS  250401        49
#
#                  DESCRIPCIO           DESCARGAR   WHATSAPP  \
# 0               CHUQUIBAMBA  www.geogpsperu.com  931381206
# 1                  EL PARCO  www.geogpsperu.com  931381206
# 2                    VALERA  www.geogpsperu.com  931381206
# 3                     NIEVA  www.geogpsperu.com  931381206
# 4    SAN FRANCISCO DEL YESO  www.geogpsperu.com  931381206
# ..                      ...                 ...        ...
# 594                   PURUS  www.geogpsperu.com  931381206
# 595                   PURUS  www.geogpsperu.com  931381206
# 596                   PURUS  www.geogpsperu.com  931381206
# 597                   PURUS  www.geogpsperu.com  931381206
# 598                   PURUS  www.geogpsperu.com  931381206
#
#                      CONTACTO Departamento Provincia UBIGEO_DEP     Año  \
# 0    juan.suyo@geogpsperu.com          NaN       NaN        NaN     NaN
# 1    juan.suyo@geogpsperu.com          NaN       NaN        NaN     NaN
# 2    juan.suyo@geogpsperu.com          NaN       NaN        NaN     NaN
# 3    juan.suyo@geogpsperu.com          NaN       NaN        NaN     NaN
# 4    juan.suyo@geogpsperu.com          NaN       NaN        NaN     NaN
# ..                        ...          ...       ...        ...     ...
# 594  juan.suyo@geogpsperu.com      UCAYALI     PURUS         25  2015.0
# 595  juan.suyo@geogpsperu.com      UCAYALI     PURUS         25  2016.0
# 596  juan.suyo@geogpsperu.com      UCAYALI     PURUS         25  2017.0
# 597  juan.suyo@geogpsperu.com      UCAYALI     PURUS         25  2020.0
# 598  juan.suyo@geogpsperu.com      UCAYALI     PURUS         25  2021.0
#
#      Total_casos
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 594          0.0
# 595          0.0
# 596          0.0
# 597          0.0
# 598          0.0
#
# [599 rows x 19 columns]

# %%
dataset_2021_prov = subdata( 2021 , "All-Peru")
dataset_2021_prov.head(5)
# Out:
#   IDPROV                                           geometry CCDD   NOMBDEP  \
# 0   0101  POLYGON ((-77.78428 -6.94651, -77.78553 -6.948...   01  AMAZONAS
# 1   0102  POLYGON ((-78.32620 -5.56382, -78.32625 -5.565...   01  AMAZONAS
# 2   0103  POLYGON ((-77.93780 -6.03777, -77.93781 -6.037...   01  AMAZONAS
# 3   0104  POLYGON ((-77.58527 -4.47289, -77.58594 -4.475...   01  AMAZONAS
# 4   0105  POLYGON ((-77.93702 -6.69093, -77.93914 -6.693...   01  AMAZONAS
#
#   CCPP      NOMBPROV CCDI                 CAPITAL  CODIGO  CNT_CCPP  \
# 0   01   CHACHAPOYAS   06             CHUQUIBAMBA  010106        39
# 1   02         BAGUA   04                EL PARCO  010204         9
# 2   03       BONGARA   11      VALERA (SAN PABLO)  010311        16
# 3   04  CONDORCANQUI   01    SANTA MARIA DE NIEVA  010401       131
# 4   05          LUYA   17  SAN FRANCISCO DEL YESO  010517        22
#
#                DESCRIPCIO           DESCARGAR   WHATSAPP  \
# 0             CHUQUIBAMBA  www.geogpsperu.com  931381206
# 1                EL PARCO  www.geogpsperu.com  931381206
# 2                  VALERA  www.geogpsperu.com  931381206
# 3                   NIEVA  www.geogpsperu.com  931381206
# 4  SAN FRANCISCO DEL YESO  www.geogpsperu.com  931381206
#
#                    CONTACTO Departamento Provincia UBIGEO_DEP  Año  \
# 0  juan.suyo@geogpsperu.com          NaN       NaN        NaN  NaN
# 1  juan.suyo@geogpsperu.com          NaN       NaN        NaN  NaN
# 2  juan.suyo@geogpsperu.com          NaN       NaN        NaN  NaN
# 3  juan.suyo@geogpsperu.com          NaN       NaN        NaN  NaN
# 4  juan.suyo@geogpsperu.com          NaN       NaN        NaN  NaN
#
#    Total_casos
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
dataset_2021_prov.dtypes
# Out:
# IDPROV            object
# geometry        geometry
# CCDD              object
# NOMBDEP           object
# CCPP              object
# NOMBPROV          object
# CCDI              object
# CAPITAL           object
# CODIGO            object
# CNT_CCPP           int64
# DESCRIPCIO        object
# DESCARGAR         object
# WHATSAPP          object
# CONTACTO          object
# Departamento      object
# Provincia         object
# UBIGEO_DEP        object
# Año              float64
# Total_casos      float64
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(20, 20))

cmap = plt.cm.get_cmap('Blues')
cmap.set_bad(color='black')

pc = dataset_2021_prov.plot(column='Total_casos', cmap=cmap, ax=ax, edgecolor='Black', linestyle='--',
                            legend=True, missing_kwds={'color': 'grey'})
pc
# Out:
# C:\Users\sriega\AppData\Local\Temp\ipykernel_14928\915309072.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues')
# <Axes: >

# %% [markdown]
# #### Use geopandas to plot the number of cases by the department for all the years using subplots. Every subplot for each year. Do not forget to indicate the color of NA values. Use this shapefile. For this task, you will have to aggregate shapefiles at the department level.

# %%
departments_shp = gpd.read_file(r'../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp')

# %%
departments_shp.head(2)
# Out:
#    OBJECTID_1  OBJECTID CCDD   NOMBDEP      CAPITAL  Shape_STAr  Shape_STLe  \
# 0           1       1.0   01  AMAZONAS  CHACHAPOYAS    3.203006   12.912088
# 1           2       2.0   02    ANCASH       HUARAZ    2.954592   11.780424
#
#    ORIG_FID  Shape_Leng  Shape_Area                    CORREO  \
# 0         0   12.912088    3.203006  juan.suyo@geogpsperu.com
# 1         1   11.780424    2.954592  juan.suyo@geogpsperu.com
#
#              CONTACTO   WHATSAPP  \
# 0  www.geogpsperu.com  931381206
# 1  www.geogpsperu.com  931381206
#
#                                             geometry
# 0  POLYGON ((-77.81399 -2.99278, -77.81483 -2.995...
# 1  POLYGON ((-77.64697 -8.05086, -77.64689 -8.051...

# %%
# Aggregate the data by department and year
agg_data = data.groupby(["Año", "Departamento"])["Casos"].sum().reset_index()

# %%
#Loop over years
years = sorted(data.Año.unique())
ncols = 3
nrows = (len(years)+ncols-1)//ncols

#creating subplots

fig, axs = plt.subplots(nrows, ncols, figsize=(15, 15))

# Loop over years
for i, year in enumerate(years):
    # Filter data for year
    year_data = agg_data[agg_data['Año'] == year]
    
    # Merge with shapefile
    merged = departments_shp.merge(year_data, left_on='NOMBDEP', right_on='Departamento')
    
    
    # Plot
    ax = axs[i // ncols, i % ncols]
    
    merged.plot(column='Casos', cmap='Blues', ax=ax, legend=True, legend_kwds={'label': 'Number of Cases'})
    ax.set_title(year)
    ax.axis('off')

    # add color for NA values
    ax.set_facecolor('red')

    

for j in range(i+1, nrows*ncols):
    axs[j // ncols, j % ncols].set_visible(False)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Subplot cases by department 2021
# Use geopandas to plot the number of cases by the department for all 2021 quarters using subplots. Every subplot for each quarter. Use a categorical legend with 5 bins. Do not forget to indicate the color of NA values. For this task, you will have to aggregate shapefiles at the department level. Hint: Use Semana variable to group by quarters.

# %%
maps2 = gpd.read_file(r'../_data/LIMITE_DISTRITAL_2020_INEI/INEI_LIMITE_DISTRITAL.shp')
maps2.head(5)
# Out:
#   CCDD    NOMBDEP CCPP    NOMBPROV CCDI      NOMBDIST          CAPITAL  \
# 0   06  CAJAMARCA   05   CONTUMAZA   04      GUZMANGO         GUZMANGO
# 1   06  CAJAMARCA   11  SAN MIGUEL   05      EL PRADO         EL PRADO
# 2   06  CAJAMARCA   11  SAN MIGUEL   09        NIEPOS           NIEPOS
# 3   06  CAJAMARCA   11  SAN MIGUEL   10  SAN GREGORIO     SAN GREGORIO
# 4   06  CAJAMARCA   12   SAN PABLO   03      SAN LUIS  SAN LUIS GRANDE
#
#    UBIGEO IDPROV  CODIGO  CNT_CCPP    DESCRIPCIO           DESCARGAR  \
# 0  060504   0605  060504        50      GUZMANGO  www.geogpsperu.com
# 1  061105   0611  061105        15      EL PRADO  www.geogpsperu.com
# 2  061109   0611  061109        41        NIEPOS  www.geogpsperu.com
# 3  061110   0611  061110        48  SAN GREGORIO  www.geogpsperu.com
# 4  061203   0612  061203         9      SAN LUIS  www.geogpsperu.com
#
#     WHATSAPP                  CONTACTO  \
# 0  931381206  juan.suyo@geogpsperu.com
# 1  931381206  juan.suyo@geogpsperu.com
# 2  931381206  juan.suyo@geogpsperu.com
# 3  931381206  juan.suyo@geogpsperu.com
# 4  931381206  juan.suyo@geogpsperu.com
#
#                                             geometry
# 0  POLYGON ((-78.91578 -7.32085, -78.91370 -7.322...
# 1  POLYGON ((-79.01679 -6.96945, -79.01581 -6.969...
# 2  POLYGON ((-79.21691 -6.85171, -79.21576 -6.851...
# 3  POLYGON ((-79.08233 -7.00544, -79.08041 -7.005...
# 4  POLYGON ((-78.87623 -7.09747, -78.87471 -7.098...

# %%
maps2 = maps2[ [ 'NOMBDEP', 'geometry' ] ]
maps2 = maps2.dissolve( by = 'NOMBDEP', aggfunc='sum' ).reset_index()
maps2
# Out:
#           NOMBDEP                                           geometry
# 0        AMAZONAS  POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 1          ANCASH  POLYGON ((-77.70189 -10.32392, -77.70434 -10.3...
# 2        APURIMAC  POLYGON ((-73.51174 -14.53852, -73.51368 -14.5...
# 3        AREQUIPA  POLYGON ((-72.72968 -16.64631, -72.73106 -16.6...
# 4        AYACUCHO  POLYGON ((-74.50188 -15.16058, -74.50191 -15.1...
# 5       CAJAMARCA  POLYGON ((-79.07326 -7.46865, -79.08528 -7.462...
# 6          CALLAO  POLYGON ((-77.10456 -12.06373, -77.10449 -12.0...
# 7           CUSCO  POLYGON ((-71.89418 -14.78954, -71.89579 -14.7...
# 8    HUANCAVELICA  POLYGON ((-75.23983 -14.04591, -75.25853 -14.0...
# 9         HUANUCO  POLYGON ((-76.80833 -10.39296, -76.81024 -10.3...
# 10            ICA  POLYGON ((-75.85580 -14.71546, -75.85540 -14.7...
# 11          JUNIN  POLYGON ((-75.62838 -12.14038, -75.62840 -12.1...
# 12    LA LIBERTAD  POLYGON ((-78.90292 -8.36708, -78.90330 -8.366...
# 13     LAMBAYEQUE  POLYGON ((-79.82045 -6.98332, -79.82121 -6.982...
# 14           LIMA  MULTIPOLYGON (((-77.05715 -12.11098, -77.05741...
# 15         LORETO  POLYGON ((-74.50177 -7.26608, -74.50407 -7.268...
# 16  MADRE DE DIOS  POLYGON ((-70.40343 -13.11693, -70.40352 -13.1...
# 17       MOQUEGUA  POLYGON ((-70.90945 -17.65336, -70.90952 -17.6...
# 18          PASCO  POLYGON ((-76.18870 -10.95996, -76.18965 -10.9...
# 19          PIURA  POLYGON ((-80.88354 -5.54662, -80.88405 -5.545...
# 20           PUNO  MULTIPOLYGON (((-70.33460 -16.20157, -70.33827...
# 21     SAN MARTIN  POLYGON ((-76.73184 -8.51609, -76.73188 -8.516...
# 22          TACNA  POLYGON ((-70.33515 -18.31557, -70.34540 -18.3...
# 23         TUMBES  POLYGON ((-80.39847 -3.98043, -80.39860 -3.980...
# 24        UCAYALI  POLYGON ((-75.12008 -8.90434, -75.12004 -8.904...

# %%
data_2021 = data[ data[ "Año" ] == 2021 ]
data_2021
# Out:
#          Año  Semana Eventos o daños   Departamento                 Distrito  \
# 1       2021      41          Dengue       MOQUEGUA                 MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA                 MOQUEGUA
# 6       2021      41          Dengue           LIMA            INDEPENDENCIA
# 7       2021      41          Dengue           LIMA  VILLA MARIA DEL TRIUNFO
# 8       2021      41          Dengue           LIMA                      ATE
# ...      ...     ...             ...            ...                      ...
# 172139  2021      49          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS                TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS                TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS                TAHUAMANU
#
#              Provincia  Ubigeo  Casos
# 1       MARISCAL NIETO  180101    NaN
# 2       MARISCAL NIETO  180101    NaN
# 6                 LIMA  150112    NaN
# 7                 LIMA  150143    NaN
# 8                 LIMA  150103    NaN
# ...                ...     ...    ...
# 172139            MANU  170203    NaN
# 172140       TAHUAMANU  170303    NaN
# 172141            MANU  170203    NaN
# 172142       TAHUAMANU  170303    NaN
# 172143       TAHUAMANU  170303    NaN
#
# [24857 rows x 8 columns]

# %%
type(data_2021["Semana"])
# Out:
# pandas.core.series.Series

# %%
#There are 52 weeks in a year. Each quarter is 13 weeks longs
data_2021["Quarter"] = np.where(data_2021["Semana"]<14, "Q1",
                   np.where(data_2021["Semana"]<27, "Q2",
                   np.where(data_2021["Semana"]<40, "Q3", "Q4")))
data_2021
# Out:
# C:\Users\sriega\AppData\Local\Temp\ipykernel_14928\3981044494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2021["Quarter"] = np.where(data_2021["Semana"]<14, "Q1",
#          Año  Semana Eventos o daños   Departamento                 Distrito  \
# 1       2021      41          Dengue       MOQUEGUA                 MOQUEGUA
# 2       2021      42          Dengue       MOQUEGUA                 MOQUEGUA
# 6       2021      41          Dengue           LIMA            INDEPENDENCIA
# 7       2021      41          Dengue           LIMA  VILLA MARIA DEL TRIUNFO
# 8       2021      41          Dengue           LIMA                      ATE
# ...      ...     ...             ...            ...                      ...
# 172139  2021      49          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172140  2021      49          Dengue  MADRE DE DIOS                TAHUAMANU
# 172141  2021      50          Dengue  MADRE DE DIOS            MADRE DE DIOS
# 172142  2021      50          Dengue  MADRE DE DIOS                TAHUAMANU
# 172143  2021      51          Dengue  MADRE DE DIOS                TAHUAMANU
#
#              Provincia  Ubigeo  Casos Quarter
# 1       MARISCAL NIETO  180101    NaN      Q4
# 2       MARISCAL NIETO  180101    NaN      Q4
# 6                 LIMA  150112    NaN      Q4
# 7                 LIMA  150143    NaN      Q4
# 8                 LIMA  150103    NaN      Q4
# ...                ...     ...    ...     ...
# 172139            MANU  170203    NaN      Q4
# 172140       TAHUAMANU  170303    NaN      Q4
# 172141            MANU  170203    NaN      Q4
# 172142       TAHUAMANU  170303    NaN      Q4
# 172143       TAHUAMANU  170303    NaN      Q4
#
# [24857 rows x 9 columns]

# %%
data_2021 = data_2021[ [ "Departamento", "Casos", "Quarter" ] ]

data_2021 = data_2021.rename({'Departamento':'NOMBDEP'}, axis =1 )

data_2021_G = data_2021.groupby( [ "NOMBDEP", "Quarter", "" ] ).sum().reset_index()

data_2021_G
# Out:
#      NOMBDEP Quarter  Casos
# 0   AMAZONAS      Q1  599.0
# 1   AMAZONAS      Q2  387.0
# 2   AMAZONAS      Q3  218.0
# 3   AMAZONAS      Q4    0.0
# 4     ANCASH      Q1    0.0
# ..       ...     ...    ...
# 79    TUMBES      Q4    0.0
# 80   UCAYALI      Q1  877.0
# 81   UCAYALI      Q2  140.0
# 82   UCAYALI      Q3   26.0
# 83   UCAYALI      Q4    0.0
#
# [84 rows x 3 columns]

# %%
data_2021_G = data_2021_G.merge( maps2, how = 'outer', on = 'NOMBDEP' )
data_2021_G
# data_2021_G = data_2021_G.rename({'geometry_x':'geometry'}, axis =1 )
# data_2021_G =data_2021_G.drop(columns=["geometry_y"])
# data_2021_G
# Out:
#          NOMBDEP Quarter  Casos  \
# 0       AMAZONAS      Q1  599.0
# 1       AMAZONAS      Q2  387.0
# 2       AMAZONAS      Q3  218.0
# 3       AMAZONAS      Q4    0.0
# 4         ANCASH      Q1    0.0
# ..           ...     ...    ...
# 83       UCAYALI      Q4    0.0
# 84      APURIMAC     NaN    NaN
# 85      AREQUIPA     NaN    NaN
# 86  HUANCAVELICA     NaN    NaN
# 87         TACNA     NaN    NaN
#
#                                            geometry_x  \
# 0   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 1   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 2   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 3   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 4   POLYGON ((-77.70189 -10.32392, -77.70434 -10.3...
# ..                                                ...
# 83  POLYGON ((-75.12008 -8.90434, -75.12004 -8.904...
# 84  POLYGON ((-73.51174 -14.53852, -73.51368 -14.5...
# 85  POLYGON ((-72.72968 -16.64631, -72.73106 -16.6...
# 86  POLYGON ((-75.23983 -14.04591, -75.25853 -14.0...
# 87  POLYGON ((-70.33515 -18.31557, -70.34540 -18.3...
#
#                                            geometry_y
# 0   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 1   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 2   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 3   POLYGON ((-78.03472 -6.74208, -78.03451 -6.741...
# 4   POLYGON ((-77.70189 -10.32392, -77.70434 -10.3...
# ..                                                ...
# 83  POLYGON ((-75.12008 -8.90434, -75.12004 -8.904...
# 84  POLYGON ((-73.51174 -14.53852, -73.51368 -14.5...
# 85  POLYGON ((-72.72968 -16.64631, -72.73106 -16.6...
# 86  POLYGON ((-75.23983 -14.04591, -75.25853 -14.0...
# 87  POLYGON ((-70.33515 -18.31557, -70.34540 -18.3...
#
# [88 rows x 5 columns]

# %%
#Subset to plot
Plot1 = data_2021_G[data_2021_G["Quarter"] == "Q1"]
Plot2 = data_2021_G[data_2021_G["Quarter"] == "Q2"]
Plot3 = data_2021_G[data_2021_G["Quarter"] == "Q3"]
Plot4 = data_2021_G[data_2021_G["Quarter"] == "Q4"]

# %%
fig, ax = plt.subplots(figsize=(20, 20))

cmap = plt.cm.get_cmap('Blues')

cmap.set_bad(color='black')

Plot1.plot( ax = ax, 
           column='Casos', 
           cmap= cmap, 
           figsize=(20, 20), 
           linestyle='--',
           edgecolor='black', 
           legend = True,  
           scheme = "User_Defined",
           classification_kwds = dict( bins = [ 400, 850, 1300, 1550, ] ),
           legend_kwds=dict(  loc='upper left',
                            bbox_to_anchor=(1.01, 1),
                            fontsize='x-large',
                            title= "Dengue Cases by Departamento - Quarter 1", 
                            title_fontsize = 'x-large', 
                            frameon= False ),
           missing_kwds={'color': 'grey'}
          )

# %%
fig, ax = plt.subplots(figsize=(20, 20))

cmap = plt.cm.get_cmap('Blues')

cmap.set_bad(color='black')

Plot2.plot( ax = ax, 
           column='Casos', 
           cmap= cmap, 
           figsize=(20, 20), 
           linestyle='--',
           edgecolor='black', 
           legend = True,  
           scheme = "User_Defined",
           classification_kwds = dict( bins = [ 400, 850, 1300, 1550, ] ),
           legend_kwds=dict(  loc='upper left',
                            bbox_to_anchor=(1.01, 1),
                            fontsize='x-large',
                            title= "Dengue Cases by Departamento - Quarter 2", 
                            title_fontsize = 'x-large', 
                            frameon= False ),
           missing_kwds={'color': 'grey'}
          )

# %%
fig, ax = plt.subplots(figsize=(20, 20))

cmap = plt.cm.get_cmap('Blues')

cmap.set_bad(color='black')

Plot3.plot( ax = ax, 
           column='Casos', 
           cmap= cmap, 
           figsize=(20, 20), 
           linestyle='--',
           edgecolor='black', 
           legend = True,  
           scheme = "User_Defined",
           classification_kwds = dict( bins = [ 400, 850, 1300, 1550, ] ),
           legend_kwds=dict(  loc='upper left',
                            bbox_to_anchor=(1.01, 1),
                            fontsize='x-large',
                            title= "Dengue Cases by Departamento - Quarter 3", 
                            title_fontsize = 'x-large', 
                            frameon= False ),
           missing_kwds={'color': 'grey'}
          )

# %%
fig, ax = plt.subplots(figsize=(20, 20))

cmap = plt.cm.get_cmap('Blues')

cmap.set_bad(color='black')

Plot4.plot( ax = ax, 
           column='Casos', 
           cmap= cmap, 
           figsize=(20, 20), 
           linestyle='--',
           edgecolor='black', 
           legend = True,  
           scheme = "User_Defined",
           classification_kwds = dict( bins = [ 400, 850, 1300, 1550, ] ),
           legend_kwds=dict(  loc='upper left',
                            bbox_to_anchor=(1.01, 1),
                            fontsize='x-large',
                            title= "Dengue Cases by Departamento - Quarter 4", 
                            title_fontsize = 'x-large', 
                            frameon= False ),
           missing_kwds={'color': 'grey'}
          )
