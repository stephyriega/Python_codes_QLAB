# %% [markdown]
# # Geocoding using googlemaps (directions)

# %% [markdown]
# For this exercise we got our own google api and token. they have been DEACTIVATED to evade the unapproved use of them.

# %%
#pip install googlemaps

# %%
#pip install camelot-py[cv] tabula-py

# %%
# Packages
import pandas as pd
import os
import urllib.request, json, csv
import numpy as np
from tqdm import tqdm_notebook as tqdm
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time
import requests
#maps
import googlemaps
#pdf
from tqdm import tqdm_notebook as tqdm
import tabula

# %%
os.environ["JAVA_HOME"] = "/path/to/java"

# %% [markdown]
# ## 1. First we import the pdf file into pandas and only keep desired rows

# %% [markdown]
# Import Data from this url. This dataset is in PDF format. You have to convert to PandasDataFrame and keep only the BBVA offices in LIMA.

# %% [markdown]
# We had to install Jave from this [link](https://www.java.com/en/download/) in order to be able to run **tabula**.

# %%
dbanco = tabula.read_pdf("https://www.bbva.pe/content/dam/public-web/peru/documents/personas/canales-de-atencion/oficinas/Oficinas-BBVA-abiertas-23.10.20.pdf", pages="all")

# %%
#Delete the empty  elements of this list
dbanco[1].dropna(how='all', axis=1, inplace=True)
dbanco
# Out:
# [                       Unnamed: 0  \
#  0                         OFICINA
#  1                    BAGUA GRANDE
#  2                        CHIMBOTE
#  3                          HUARAZ
#  4              MEGAPLAZA CHIMBOTE
#  5                             NaN
#  6         MERCADO MODELO CHIMBOTE
#  7                  NUEVO CHIMBOTE
#  8                             NaN
#  9                     ANDAHUAYLAS
#  10                     LAS BAMBAS
#  11                       AREQUIPA
#  12              CAMANA - AREQUIPA
#  13                          CAYMA
#  14                 CERRO COLORADO
#  15                    EL PEDREGAL
#  16                            NaN
#  17  JOSE LUIS BUSTAMANTE Y RIVERO
#  18                            NaN
#  19       MALL AVENTURA PLAZA  AQP
#  20                            NaN
#  21          MIRAFLORES - AREQUIPA
#  22              PARQUE INDUSTRIAL
#  23                     SAN CAMILO
#  24                      YANAHUARA
#  25          UNIVERSIDAD SAN PABLO
#  26                            NaN
#  27                       AYACUCHO
#  28                 C.C. EL QUINDE
#  29                      CAJAMARCA
#  30                          CHOTA
#  31                           JAEN
#  32                          CUSCO
#  33                 LARAPA - CUZCO
#  34                    QUILLABAMBA
#  35               REAL PLAZA CUSCO
#  36                        TINTAYA
#  37                        WANCHAQ
#  38                        HUANUCO
#  39                            NaN
#  40         PLAZA DE ARMAS HUANUCO
#  41                    TINGO MARIA
#  42                        CHINCHA
#  43                  EL QUINDE ICA
#  44                            ICA
#  45                          PISCO
#  46               SAN MARTIN - ICA
#  47                CHILCA HUANCAYO
#
#                                             Unnamed: 1            Unnamed: 2  \
#  0                                           DIRECCION              DISTRITO
#  1                                AV. CHACHAPOYAS 2044          BAGUA GRANDE
#  2              AV. FRANCISCO BOLOGNESI 696 - CHIMBOTE              CHIMBOTE
#  3        CALLE 2 ESQ. JR. JOSE SUCRE - PLAZA DE ARMAS                HUARAZ
#  4   AV. VICTOR R. HAYA DE LA TORRE 4694, LC B4 Y B...              CHIMBOTE
#  5                                         GRAN CHAVIN                   NaN
#  6   JR. ELIAS AGUIRRE 498, ESQ. CON JR. LADISLAO E...              CHIMBOTE
#  7   CA. PROGR. VIVIENDA ETAPA I, UNIDAD U-1, NÚCLE...        NUEVO CHIMBOTE
#  8                           BUENOS AIRES, MZ. F LT. 1                   NaN
#  9                                        AV. PERU 342           ANDAHUAYLAS
#  10         BARRIO PATRÓN SANTIAGO S/N, PLAZA DE ARMAS         CHALHUAHUACHO
#  11                       SAN FRANCISCO 108 - AREQUIPA              AREQUIPA
#  12        JR. 28 DE JULIO 405, ESQ. CON JR. NAVARRETE                CAMANA
#  13                       AV. EJERCITO 710 - YANAHUARA             YANAHUARA
#  14                           AV. AVIACION 602, LC-118        CERRO COLORADO
#  15  HABILIT. URBANA CENTRO POBLADO DE SERV. BÁSICO...                 MAJES
#  16                               PEDREGAL MZ. G LT. 2                   NaN
#  17  MZ E SUB LOTE 6A COOPERATIVA VIVIENDA EMPLEADO...  JOSE LUIS BUSTAMANTE
#  18                                          LANIFICIO              Y RIVERO
#  19  Local LF-03 - Av. Porongoche N° 500, distrito ...              AREQUIPA
#  20               provincia y departamento de Arequipa                   NaN
#  21  AV. VENEZUELA S/N, C.C. LA NEGRITA TDA. 1 - MI...            MIRAFLORES
#  22                           CALLE JACINTO IBAÑEZ 521              AREQUIPA
#  23                          CALLE PERU 324 - AREQUIPA              AREQUIPA
#  24  AV. JOSE ABELARDO QUIÑONES 700, URB. BARRIO MA...             YANAHUARA
#  25  URB. LA CAMPIÑA PAISAJISTA S/N QUINTA VIVANCO ...              AREQUIPA
#  26                      CATÓLICA SAN PABLO - AREQUIPA                   NaN
#  27   PORTAL UNIÓN N.- 24, ESQ. CON JR. 9 DE DICIEMBRE              AYACUCHO
#  28    JR. SOR MANUELA GIL 151, LOCAL LC-323, 325, 327             CAJAMARCA
#  29                 JR. TARAPACA 719 - 721 - CAJAMARCA             CAJAMARCA
#  30                     AV. ANAXIMANDRO VEGA 413 - 417                 CHOTA
#  31                               CAL SAN MARTIN. 1499                  JAEN
#  32                             AV. EL SOL 366 - CUSCO                 CUSCO
#  33              URB. CACHIMAYO  C-21-A  SAN SEBASTIAN          SAN JERONIMO
#  34              AV. BOLOGNESI 155 - 157 - QUILLABAMBA             SANTA ANA
#  35            AV. COLLASUYO 2964 Y 3060, LOCAL LC-109                 CUSCO
#  36                          CAMPAMENTO MINERO TINTAYA               ESPINAR
#  37             AV. GARCILASO 300 / HUASCAR - WANCHACK               WANCHAQ
#  38  JR. INDEPENDENCIA 1601-1799, CC REAL PLAZA HUA...               HUANUCO
#  39                                            B02-B04                   NaN
#  40                            JR. DOS DE MAYO N° 1137               HUANUCO
#  41                                   AV. RAYMONDI 543             RUPA-RUPA
#  42                       MARISCAL BENAVIDES 117 - 125          CHINCHA ALTA
#  43  AV. LOS MAESTROS 206, LF-100 / LF- 111, FUNDO ...                   ICA
#  44                             JR. LIBERTAD 141 - 165                   ICA
#  45  ESQ.  PEREZ FIGUEROLA / AV. INDEPENDENCIA PZ. ...                 PISCO
#  46                                AV. SAN MARTIN 1144                   ICA
#  47                    AV. 9 DE DICIEMBRE 517, LC 1088                CHILCA
#
#         Unnamed: 3    Unnamed: 4
#  0       PROVINCIA  DEPARTAMENTO
#  1       UTCUBAMBA      AMAZONAS
#  2           SANTA        ANCASH
#  3          HUARAZ        ANCASH
#  4           SANTA        ANCASH
#  5             NaN           NaN
#  6           SANTA        ANCASH
#  7           SANTA        ANCASH
#  8             NaN           NaN
#  9     ANDAHUAYLAS      APURIMAC
#  10     COTABAMBAS      APURIMAC
#  11       AREQUIPA      AREQUIPA
#  12         CAMANA      AREQUIPA
#  13       AREQUIPA      AREQUIPA
#  14       AREQUIPA      AREQUIPA
#  15       CAYLLOMA      AREQUIPA
#  16            NaN           NaN
#  17       AREQUIPA      AREQUIPA
#  18            NaN           NaN
#  19       AREQUIPA      AREQUIPA
#  20            NaN           NaN
#  21       AREQUIPA      AREQUIPA
#  22       AREQUIPA      AREQUIPA
#  23       AREQUIPA      AREQUIPA
#  24       AREQUIPA      AREQUIPA
#  25       AREQUIPA      AREQUIPA
#  26            NaN           NaN
#  27       HUAMANGA      AYACUCHO
#  28      CAJAMARCA     CAJAMARCA
#  29      CAJAMARCA     CAJAMARCA
#  30          CHOTA     CAJAMARCA
#  31           JAEN     CAJAMARCA
#  32          CUSCO         CUSCO
#  33          CUSCO         CUSCO
#  34  LA CONVENCION         CUSCO
#  35          CUSCO         CUSCO
#  36        ESPINAR         CUSCO
#  37          CUSCO         CUSCO
#  38        HUANUCO       HUANUCO
#  39            NaN           NaN
#  40        HUANUCO       HUANUCO
#  41  LEONCIO PRADO       HUANUCO
#  42        CHINCHA           ICA
#  43            ICA           ICA
#  44            ICA           ICA
#  45          PISCO           ICA
#  46            ICA           ICA
#  47       HUANCAYO         JUNIN  ,
#                        EL TAMBO  \
#  0                     HUANCAYO
#  1                    LA MERCED
#  2                     LA OROYA
#  3                   PICHANAQUI
#  4                          NaN
#  5          REAL PLAZA HUANCAYO
#  6                       SATIPO
#  7                        TARMA
#  8                       CHEPEN
#  9       EL PORVENIR (Trujillo)
#  10            HUSARES DE JUNIN
#  11            LARCO - TRUJILLO
#  12         MALL PLAZA TRUJILLO
#  13                         NaN
#  14  MERCADO MAYORISTA TRUJILLO
#  15        OVALO LARCO TRUJILLO
#  16                         NaN
#  17                 OVALO PAPAL
#  18                         NaN
#  19                   PACASMAYO
#  20                   PRIMAVERA
#  21         REAL PLAZA TRUJILLO
#  22                    TRUJILLO
#  23                    CHICLAYO
#  24                  LAMBAYEQUE
#  25             LEGUIA CHICLAYO
#  26        MDO. MODELO CHICLAYO
#  27           METRO SANTA ELENA
#  28                 MOSHOQUEQUE
#  29         REAL PLAZA CHICLAYO
#  30                 CAMINO REAL
#  31                 28 DE JULIO
#  32            ABANCAY-CONGRESO
#  33                  AEROPUERTO
#  34                ANGAMOS ESTE
#  35          ANGAMOS OPEN PLAZA
#  36                       APOLO
#  37                    ARAMBURU
#  38                    ARENALES
#  39                 AV. CENTRAL
#  40            AV. DEL EJERCITO
#  41                    AV. PERU
#  42                   AV. SUCRE
#  43                    AVIACIÓN
#  42                                      AV. SUCRE 970          PUEBLO LIBRE
#  43                            AV. AVIACION  2801-2805             SAN BORJA
#
#         HUANCAYO        JUNIN
#  0      HUANCAYO        JUNIN
#  1   CHANCHAMAYO        JUNIN
#  2         YAULI        JUNIN
#  3   CHANCHAMAYO        JUNIN
#  4           NaN          NaN
#  5      HUANCAYO        JUNIN
#  6        SATIPO        JUNIN
#  7         TARMA        JUNIN
#  8        CHEPEN  LA LIBERTAD
#  9      TRUJILLO  LA LIBERTAD
#  10     TRUJILLO  LA LIBERTAD
#  11     TRUJILLO  LA LIBERTAD
#  12     TRUJILLO  LA LIBERTAD
#  13          NaN          NaN
#  14     TRUJILLO  LA LIBERTAD
#  15     TRUJILLO  LA LIBERTAD
#  16          NaN          NaN
#  17     TRUJILLO  LA LIBERTAD
#  18          NaN          NaN
#  19    PACASMAYO  LA LIBERTAD
#  20     TRUJILLO  LA LIBERTAD
#  21     TRUJILLO  LA LIBERTAD
#  22     TRUJILLO  LA LIBERTAD
#  23     CHICLAYO   LAMBAYEQUE
#  24   LAMBAYEQUE   LAMBAYEQUE
#  25     CHICLAYO   LAMBAYEQUE
#  26     CHICLAYO   LAMBAYEQUE
#  27     CHICLAYO   LAMBAYEQUE
#  28     CHICLAYO   LAMBAYEQUE
#  29     CHICLAYO   LAMBAYEQUE
#  30         LIMA         LIMA
#  31         LIMA         LIMA
#  32         LIMA         LIMA
#  33         LIMA         LIMA
#  34         LIMA         LIMA
#  35         LIMA         LIMA
#  36         LIMA         LIMA
#  37         LIMA         LIMA
#  38         LIMA         LIMA
#  39         LIMA         LIMA
#  40         LIMA         LIMA
#  41         LIMA         LIMA
#  42         LIMA         LIMA
#  43         LIMA         LIMA  ,
#                         BACKUS  \
#  0                    BARRANCA
#  1                    BARRANCO
#  2                  BASE NAVAL
#  3                  BELLAVISTA
#  4                   BENAVIDES
#  5                     BOLIVAR
#  6                       BREÑA
#  7                 C.C. AURORA
#  8           C.C. CANTA CALLAO
#  9                         NaN
#  10                 C.C. FIORI
#  11             C.C. HIGUERETA
#  12            C.C. MONTERRICO
#  13          C.C.LAS GARDENIAS
#  14                  C.C.RISSO
#  15             C.C.SAN ISIDRO
#  16             C.C.SAN MIGUEL
#  17                        NaN
#  18                  C.C.SUCRE
#  19                     CALLAO
#  20                    CAMACHO
#  21                     CAMANA
#  22           CAMINOS DEL INCA
#  23        CANADA-LA ROSA TORO
#  24          CANAVAL Y MOREYRA
#  25               CANTO GRANDE
#  26                        NaN
#  27                     CAÑETE
#  28                        NaN
#  29                      CAPON
#  30                 CARABAYLLO
#  31                  CAVENECIA
#  32  CC REAL PLAZA SANTA CLARA
#  33              CC. EL TRIGAL
#  34         CC. REAL PLAZA PRO
#  35            CEDROS DE VILLA
#  36                 CHACARILLA
#  37                        NaN
#  38                    CHANCAY
#  39                 CHORRILLOS
#  40                    CHOSICA
#  41                        NaN
#  42          CLUB REGATAS LIMA
#  43                   COLONIAL
#  44         COMANDANTE ESPINAR
#
ALLE OMEGA 149 PARQUE INDUSTRIAL DEL CALLAO                 CALLAO
#  44           AV. COMANDANTE ESPINAR N° 374, 384 y 388             MIRAFLORES
#
#          LIMA LIMA.1
#  0   BARRANCA   LIMA
#  1       LIMA   LIMA
#  2       LIMA   LIMA
#  3       LIMA   LIMA
#  4       LIMA   LIMA
#  5       LIMA   LIMA
#  6       LIMA   LIMA
#  7       LIMA   LIMA
#  8       LIMA   LIMA
#  9        NaN    NaN
#  10      LIMA   LIMA
#  11      LIMA   LIMA
#  12      LIMA   LIMA
#  13      LIMA   LIMA
#  14      LIMA   LIMA
#  15      LIMA   LIMA
#  16      LIMA   LIMA
#  17       NaN    NaN
#  18      LIMA   LIMA
#  19      LIMA   LIMA
#  20      LIMA   LIMA
#  21      LIMA   LIMA
#  22      LIMA   LIMA
#  23      LIMA   LIMA
#  24      LIMA   LIMA
#  25      LIMA   LIMA
#  26       NaN    NaN
#  27    CAÑETE   LIMA
#  28       NaN    NaN
#  29      LIMA   LIMA
#  30      LIMA   LIMA
#  31      LIMA   LIMA
#  32      LIMA   LIMA
#  33      LIMA   LIMA
#  34      LIMA   LIMA
#  35      LIMA   LIMA
#  36      LIMA   LIMA
#  37       NaN    NaN
#  38    HUARAL   LIMA
#  39      LIMA   LIMA
#  40      LIMA   LIMA
#  41       NaN    NaN
#  42      LIMA   LIMA
#  43      LIMA   LIMA
#  44      LIMA   LIMA  ,
#                          COMAS  \
#  0              CONQUISTADORES
#  1                      CORPAC
#  2                      COVIDA
#  3                      CRONOS
#  4   CUARTEL GRAL.DEL EJERCITO
#  5              DAMERO GAMARRA
#  6               DOMINGO CUETO
#  7                 DOS DE MAYO
#  8                         NaN
#  9                 EL AGUSTINO
#  10                    EL MURO
#  11                        NaN
#  12                    EL PINO
#  13                    EL POLO
#  14                  EL PUERTO
#  15                 EL REMANSO
#  16                 EL RETABLO
#  17                        NaN
#  18                     EL SOL
#  19                        NaN
#  20                  EL TREBOL
#  21                    ESSALUD
#  22                    FAUCETT
#  23                  FAUCETT 2
#  24                        NaN
#  25                    GAMARRA
#  26                 GRAN CHIMU
#  27                        NaN
#  28         GRIMALDO DEL SOLAR
#  29            GUARDIA CHALACA
#  30            HIPOLITO UNANUE
#  31                     HUACHO
#  32                     HUARAL
#  33                    HUAYCAN
#  34                        NaN
#  35                 INGENIERIA
#  36                  IZAGUIRRE
#  37         JAVIER PRADO OESTE
#  38                JESUS MARIA
#  39               JOCKEY PLAZA
#  40                        NaN
#  41              JORGE BASADRE
#  42                 LA COLMENA
#  43                LA ENCALADA
#  44                LA FLORESTA
#  45                  LA MARINA
#  46                        NaN
#  47                  LA MOLINA
#
#                                AV. TUPAC AMARU N° 1175               COMAS.1  \
#  0                            AV. CONQUISTADORES 1099.            SAN ISIDRO
#  1                               CALLE 23  #273 CORPAC            SAN ISIDRO
#  2   Av. Antunez de Mayolo No. 1400,1236 Distrito L...            LOS OLIVOS
#  3   AV. EL DERBY 055, LC 4, URB. LIMA POLO AND HUN...     SANTIAGO DE SURCO
#  4   INTERIOR CTEL. GRAL. DEL EJERCITO:AV. BOULEVAR...             SAN BORJA
AV. LA MOLINA MZ. B LOTE 08, URB. RESIDENCIAL ...             LA MOLINA
#
#        LIMA LIMA.1
#  0     LIMA   LIMA
#  1     LIMA   LIMA
#  2     LIMA   LIMA
#  3     LIMA   LIMA
#  4     LIMA   LIMA
#  5     LIMA   LIMA
#  6     LIMA   LIMA
#  7     LIMA   LIMA
#  8      NaN    NaN
#  9     LIMA   LIMA
#  10    LIMA   LIMA
#  11     NaN    NaN
#  12    LIMA   LIMA
#  13    LIMA   LIMA
#  14    LIMA   LIMA
#  15    LIMA   LIMA
#  16    LIMA   LIMA
#  17     NaN    NaN
#  18    LIMA   LIMA
#  19     NaN    NaN
#  20    LIMA   LIMA
#  21    LIMA   LIMA
#  22    LIMA   LIMA
#  23    LIMA   LIMA
#  24     NaN    NaN
#  25    LIMA   LIMA
#  26    LIMA   LIMA
#  27     NaN    NaN
#  28    LIMA   LIMA
#  29    LIMA   LIMA
#  30    LIMA   LIMA
#  31  HUAURA   LIMA
#  32  HUARAL   LIMA
#  33    LIMA   LIMA
#  34     NaN    NaN
#  35    LIMA   LIMA
#  36    LIMA   LIMA
#  37    LIMA   LIMA
#  38    LIMA   LIMA
#  39    LIMA   LIMA
#  40     NaN    NaN
#  41    LIMA   LIMA
#  42    LIMA   LIMA
#  43    LIMA   LIMA
#  44    LIMA   LIMA
#  45    LIMA   LIMA
#  46     NaN    NaN
#  47    LIMA   LIMA  ,
#                             LA PERLA  \
#  0                       LA PLANICIE
#  1                               NaN
#  2                         LA RAMBLA
#  3                               NaN
#  4                        LA ROTONDA
#  5                       LA VICTORIA
#  6                    LARCO - TARATA
#  7                      LAS BEGONIAS
#  8                        LAS FLORES
#  9                               NaN
#  10                      LAS TIENDAS
#  11                             LIMA
#  12                  LIMA CARGO CITY
#  13                        LIMATAMBO
#  14                            LINCE
#  15                       LOS ALAMOS
#  16                              NaN
#  17                       LOS OLIVOS
#  18                       LOS ROBLES
#  19                      LOS ROSALES
#  20                            LURÍN
#  21                              NaN
#  22                        MAGDALENA
#  23                             MALA
#  24       MALL AVENTURA PLAZA CALLAO
#  25                              NaN
#  26  MALL AVENTURA PLAZA SANTA ANITA
#  27                     MALL DEL SUR
#  28                              NaN
#  29                          MARANGA
#  30            MDO PROD. SANTA ANITA
#  31                              NaN
#  32   MEGA EXPRESS VILLA EL SALVADOR
#  33                       MEGA PLAZA
#  34                              NaN
#  35             METRO PLAZA CASTILLA
#  36                              NaN
#  37                           MEXICO
#  38                            MINKA
#  39                       MIRAFLORES
#  40                      MONTEGRANDE
#  41                       MULTIPLAZA
#  42                  NACIONES UNIDAS
#  43                NICOLAS ARRIOLA 1
#  44                NICOLAS ARRIOLA 2
#  45                   NICOLAS AYLLON
#  46                         ORRANTIA
#  47                 OVALO 200 MILLAS
#  48                 OVALO MIRAFLORES
#
#                                     AV. SAENZ PEÑA 936             CALLAO  \
#  0   AV. RICARDO E. APARICIO 675, MZ. H LT. 1 - URB...          LA MOLINA
#  1                                       LT. C, SEC. 1                NaN
#  2   AV. JAVIER PRADO ESTE 2010, MZ. I-2, LC 133-13...          SAN BORJA
#  3                                           SAN BORJA                NaN
#  4    AV. LA FONTANA 371, MZ. A LT. 7, URB. LA FON
#  7     LIMA   LIMA
#  8     LIMA   LIMA
#  9      NaN    NaN
#  10    LIMA   LIMA
#  11    LIMA   LIMA
#  12    LIMA   LIMA
#  13    LIMA   LIMA
#  14    LIMA   LIMA
#  15    LIMA   LIMA
#  16     NaN    NaN
#  17    LIMA   LIMA
#  18    LIMA   LIMA
#  19    LIMA   LIMA
#  20    LIMA   LIMA
#  21     NaN    NaN
#  22    LIMA   LIMA
#  23  CAÑETE   LIMA
#  24    LIMA   LIMA
#  25     NaN    NaN
#  26    LIMA   LIMA
#  27    LIMA   LIMA
#  28     NaN    NaN
#  29    LIMA   LIMA
#  30    LIMA   LIMA
#  31     NaN    NaN
#  32    LIMA   LIMA
#  33    LIMA   LIMA
#  34     NaN    NaN
#  35    LIMA   LIMA
#  36     NaN    NaN
#  37    LIMA   LIMA
#  38    LIMA   LIMA
#  39    LIMA   LIMA
#  40    LIMA   LIMA
#  41    LIMA   LIMA
#  42    LIMA   LIMA
#  43    LIMA   LIMA
#  44    LIMA   LIMA
#  45    LIMA   LIMA
#  46    LIMA   LIMA
#  47    LIMA   LIMA
#  48    LIMA   LIMA  ,
#                    OVALO NARANJAL  \
#  0                 ÓVALO QUIÑONEZ
#  1                          PALAO
#  2                          PANDO
#  3                          PARDO
#  4                   PARINACOCHAS
#  5                PARQUE CASTILLA
#  6           PARQUE DE LA AMISTAD
#  7                            NaN
#  8                         PARURO
#  9         PASEO DE LA CASTELLANA
#  10                 PLAZA BUTTERS
#  11          PLAZA DEL SOL HUACHO
#  12              PLAZA LIMA NORTE
#  13                           NaN
#  14                PLAZA LIMA SUR
#  15                PLAZA SAN JOSÉ
#  16                           NaN
#  17                   PLAZA UNIÓN
#  18  PQUE. IND. VILLA EL SALVADOR
#  19                           PRO
#  20                 PUENTE PIEDRA
#  21                           NaN
#  22                     PURUCHUCO
#  23                           NaN
#  24      REAL PLAZA CENTRO CIVICO
#  25                           NaN
#  26          REAL PLAZA SALAVERRY
#  27                        REPSOL
#  28                 RICARDO PALMA
#  29                         RIMAC
#  30                     RINCONADA
#  31                     SALAMANCA
#  32                     SALAVERRY
#  33                           NaN
#  34            SAMUEL DEL ALCAZAR
#  35                   SAN ANTONIO
#  36                     SAN BORJA
#  37                 SAN BORJA SUR
#  38                           NaN
#  39                    SAN FELIPE
#  40              SAN FELIPE COMAS
#  41                           NaN
#  42                    SAN ISIDRO
#  43        SAN JUAN DE MIRAFLORES
#  44                           NaN
#  45                      SAN LUIS
#  46          SAN MARTIN DE PORRES
#  47                    SAN RAFAEL
#  48                   SANTA ANITA
#
#                     AV. NARANJAL 1425, LOTE 13, MZ I-2            LOS OLIVOS  \
#  0     AV. GUARDIA CIVIL N° 787, URB. CORPAC 3RA. ZONA             SAN BORJA
#  1   AVENIDA ALFREDO MENDIOLA 821-827 - URB. PALAO,...  SAN MARTIN DE PORRES
#  2                      AV. LA MARINA 2300, URB. PANDO            SAN MIGUEL
#  3                           AV. PARDO 791 - 793 - 795            MIRAFLORES
#  4     LIMA   LIMA
#  5     LIMA   LIMA
#  6     LIMA   LIMA
#  7      NaN    NaN
#  8     LIMA   LIMA
#  9     LIMA   LIMA
#  10    LIMA   LIMA
#  11  HUAURA   LIMA
#  12    LIMA   LIMA
#  13     NaN    NaN
#  14    LIMA   LIMA
#  15    LIMA   LIMA
#  16     NaN    NaN
#  17    LIMA   LIMA
#  18    LIMA   LIMA
#  19    LIMA   LIMA
#  20    LIMA   LIMA
#  21     NaN    NaN
#  22    LIMA   LIMA
#  23     NaN    NaN
#  24    LIMA   LIMA
#  25     NaN    NaN
#  26    LIMA   LIMA
#  27    LIMA   LIMA
#  28    LIMA   LIMA
#  29    LIMA   LIMA
#  30    LIMA   LIMA
#  31    LIMA   LIMA
#  32    LIMA   LIMA
#  33     NaN    NaN
#  34    LIMA   LIMA
#  35    LIMA   LIMA
#  36    LIMA   LIMA
#  37    LIMA   LIMA
#  38     NaN    NaN
#  39    LIMA   LIMA
#  40    LIMA   LIMA
#  41     NaN    NaN
#  42    LIMA   LIMA
#  43    LIMA   LIMA
#  44     NaN    NaN
#  45    LIMA   LIMA
#  46    LIMA   LIMA
#  47    LIMA   LIMA
#  48    LIMA   LIMA  ,
#                   SANTA CRUZ  \
#  0              SANTA MONICA
#  1        SEBASTIÁN BARRANCA
#  2                       NaN
#  3     SEPARADORA INDUSTRIAL
#  4     STRIP CENTER PROCERES
#  5                       NaN
#  6                 SURQUILLO
#  7             TOMAS MARSANO
#  8      UNIVERSIDAD CATOLICA
#  9      UNIVERSITARIA FREIRE
#  10           V. A. BELAUNDE
#  11             VALLE SHARON
#  12                      NaN
#  13           VARGAS MACHUCA
#  14                      NaN
#  15           VELASCO ASTETE
#  16              VENEZUELA 1
#  17              VENEZUELA 2
#  18              VENEZUELA 3
#  19               VENTANILLA
#  20        VILLA EL SALVADOR
#  21                      NaN
#  22  VILLA MARIA DEL TRIUNFO
#  23                      NaN
#  24             VILLA MARINA
#  25                  VITARTE
#  26                   ZARATE
#  27                      NaN
#  28    STRIP CENTER BARRANCA
#  29                 ALMENARA
#  30          TMR CAMINO REAL
#  31             EMBAJADA USA
#  32                    USAID
#  33                      NaN
#  34      NESTLE-DONOFRIO 164
#  35   BIENESTAR DE LA MARINA
#  36                  SEDAPAL
#  37                      NaN
#  38          ESPECIAL SENATI
#  39           VILLA INFANTAS
#  40                      NaN
#  41                    BELEN
#  42                  IQUITOS
#  43                 SAN JUAN
#  44               YURIMAGUAS
#  45         PUERTO MALDONADO
#  46                      ILO
#  47                 MOQUEGUA
#  48                      NaN
#
#                                  Av. Santa Cruz N° 695         MIRAFLORES  \
#  0                                 AV. JUAN PEZET 1425         SAN ISIDRO
#  1   AV. IQUITOS 795-799, ESQ. CON SEBASTIÁN BARRAN...        LA VICTORIA
#  2                                                 213                NaN
#  3                                   AV. LA MOLINA 540          LA MOLINA
#  4   AV. LOS PROCERES (ANTES AV. GUARDIA CIVIL) 100...  SANTIAGO DE SURCO
#  5                                  FUNDO SANTA AMALIA                NaN
#  6                               AV. ANGAMOS ESTE 1256          SURQUILLO
#  7                            AV. TOMAS MARSANO N° 399          SURQUILLO
#  8   AV. UNIVERSITARIA CDRA. 18 - INTERIOR U. CATOLICA         SAN MIGUEL
#  9     AV. UNIVERSITARIA N° 727, URB. PANDO 4TA. ETAPA         SAN MIGUEL
#  10  CA. VICTOR A. BELAUNDE ESTE 101 URB. POPULAR R
#  7             LIMA           LIMA
#  8             LIMA           LIMA
#  9             LIMA           LIMA
#  10            LIMA           LIMA
#  11            LIMA           LIMA
#  12             NaN            NaN
#  13            LIMA           LIMA
#  14             NaN            NaN
#  15            LIMA           LIMA
#  16            LIMA           LIMA
#  17            LIMA           LIMA
#  18            LIMA           LIMA
#  19            LIMA           LIMA
#  20            LIMA           LIMA
#  21             NaN            NaN
#  22            LIMA           LIMA
#  23             NaN            NaN
#  24            LIMA           LIMA
#  25            LIMA           LIMA
#  26            LIMA           LIMA
#  27             NaN            NaN
#  28        BARRANCA           LIMA
#  29            LIMA           LIMA
#  30            LIMA           LIMA
#  31            LIMA           LIMA
#  32            LIMA           LIMA
#  33             NaN            NaN
#  34            LIMA           LIMA
#  35            LIMA           LIMA
#  36            LIMA           LIMA
#  37             NaN            NaN
#  38            LIMA           LIMA
#  39            LIMA           LIMA
#  40             NaN            NaN
#  41          MAYNAS         LORETO
#  42          MAYNAS         LORETO
#  43          MAYNAS         LORETO
#  44   ALTO AMAZONAS         LORETO
#  45       TAMBOPATA  MADRE DE DIOS
#  46             ILO       MOQUEGUA
#  47  MARISCAL NIETO       MOQUEGUA
#  48             NaN            NaN  ,
#             CERRO DE PASCO  \
#  0                     NaN
#  1        PASEO MEGA PIURA
#  2                     NaN
#  3       MDO. MODELO PIURA
#  4        OPEN PLAZA PIURA
#  5                     NaN
#  6                   PAITA
#  7                   PIURA
#  8        REAL PLAZA PIURA
#  9                     NaN
#  10     SANTA ROSA SULLANA
#  11                    NaN
#  12                SULLANA
#  13                 TALARA
#  14   TMR PASEO MEGA PIURA
#  15                    NaN
#  16                JULIACA
#  17                   PUNO
#  18     REAL PLAZA JULIACA
#  19                    NaN
#  20        BARRIO COMERCIO
#  21  BELLAVISTA SAN MARTIN
#  22                JUANJUI
#  23                    NaN
#  24              MOYOBAMBA
#  25                  RIOJA
#  26               TARAPOTO
#  27              BOLOGNESI
#  28                  TACNA
#  29                 TUMBES
#  30             7 DE JUNIO
#  31                    NaN
#  32    OPEN PLAZA PUCALLPA
#  33                    NaN
#  34               PUCALLPA
#  35                    NaN
#
#     JR. JOSE DE SAN MARTIN. EDIFICIO 2. CENTRO COMERCIAL SAN    YANACOCHA  \
#  0                                          JUAN PAMPA                NaN
#  1   Av. RAMON MUJICA N° 108, LOCAL 108-A, URBANIZA...              PIURA
#  2                                               CHIPE                NaN
#  3                              AV. SANCHEZ CERRO 1234              PIURA
#  4   AV. MARISCAL CÁCERES, ESQ. AV. IRAZOLA, SUB LT...              PIURA
#  5                                     URB. MIRAFLORES                NaN
#  6                                    JR. JUNÍN N° 263              PAITA
#  7              CALLE TACNA 598 / AYACUCHO 440 - PIURA              PIURA
#  8   AV. SÁNCHEZ CERRO, SUB LOTE NÚMERO 234 - 239A,...              PIURA
#  9                                                  02                NaN
#  10  AV. PANAMERICANA 461 CON CA. SANTO TORIBIO, LC...            SULLANA
#  11                                         SANTA ROSA                NaN
#  12                       JR. SAN MARTIN 900 - SULLANA            SULLANA
#  13                 CENTRO CIVICO 159 - BREA Y PARIÑAS            PARIÑAS
#  14  Av. RAMON MUJICA N° 108, OFICINA N° 201, URBAN...              PIURA
#  15                                              CHIPE                NaN
#  16                        JR. SAN ROMAN 441 - JULIACA            JULIACA
#  17                           JR. LIMA 400 - 411 -PUNO               PUNO
#  18  JR. SAN MARTIN 218 Y JR. TUMBES 499, CC REAL P...            JULIACA
#  19                                           LC LS-02                NaN
#  20            JR. TAHUANTINSUYO  298, BARRIO COMERCIO           TARAPOTO
#  21   ESQ AV SAN MARTIN C-5 Y AV. AUGUSTO B LEGUÍA C-7         BELLAVISTA
#  22           ESQUINA JIRÓN HUALLAGA CON EL JIRÓN GRAU            JUANJUI
#  23                                                NaN                NaN
#  24                             JR. SAN MARTIN 490-494          MOYOBAMBA
#  25            JR. DOS DE MAYO 702 - BARRIO CASCAYUNGA              RIOJA
#  26                            JR. RAMIREZ HURTADO 149           TARAPOTO
#  27                           AV. CORONEL MENDOZA 1337              TACNA
#  28                         AV. SAN MARTIN 665 - TACNA              TACNA
#  29                                    JR. BOLIVAR 237             TUMBES
#  30                           JIRÓN 7 DE JUNIO N.- 201           CALLERIA
#  31                                                NaN                NaN
#  32  AV. CENTENARIO 2086 Y 2192, JR. LAUREANO DEL Á...        YARINACOCHA
#  33                                  AV. AMAZONAS 2752                NaN
#  34                     ESQUINA UCAYALI Y RAYMONDI 699           CALLERIA
#  35                                                NaN                NaN
#
#           PASCO     PASCO.1
#  0          NaN         NaN
#  1        PIURA       PIURA
#  2          NaN         NaN
#  3        PIURA       PIURA
#  4        PIURA       PIURA
#  5          NaN         NaN
#  6        PAITA       PIURA
#  7        PIURA       PIURA
#  8        PIURA       PIURA
#  9          NaN         NaN
#  10     SULLANA       PIURA
#  11         NaN         NaN
#  12     SULLANA       PIURA
#  13      TALARA       PIURA
#  14       PIURA       PIURA
#  15         NaN         NaN
#  16   SAN ROMAN        PUNO
#  17        PUNO        PUNO
#  18   SAN ROMAN        PUNO
#  19         NaN         NaN
#  20  SAN MARTIN  SAN MARTIN
#  21  BELLAVISTA  SAN MARTIN
#  22    MARISCAL  SAN MARTIN
#  23     CÁCERES         NaN
#  24   MOYOBAMBA  SAN MARTIN
#  25       RIOJA  SAN MARTIN
#  26  SAN MARTIN  SAN MARTIN
#  27       TACNA       TACNA
#  28       TACNA       TACNA
#  29      TUMBES      TUMBES
#  30     CORONEL     UCAYALI
#  31    PORTILLO         NaN
#  32     CORONEL     UCAYALI
#  33    PORTILLO         NaN
#  34     CORONEL     UCAYALI
#  35    PORTILLO         NaN  ]

# %%
#order the observations in groups: "oficina", "direccion", "distrito", "provincia", "departamento
for i in range(len(dbanco)):
    dbanco[i] = dbanco[i].reset_index().T.reset_index().T.reset_index()
    dbanco[i].drop(dbanco[i].iloc[:, 0:2], axis = 1, inplace=True)
    dbanco[i].set_axis(["oficina", "direccion", "distrito", "provincia", "departamento"], axis=1, inplace=True)

# %%
# we eliminate the first 2 columns that were empty and wronged processed in the first page
dbanco[0]= dbanco[0].iloc[2:, :]

# %%
#Concatenate the data
bbva_peru = pd.concat(dbanco, ignore_index= True)
bbva_peru.head(2)
# Out:
#         oficina                               direccion      distrito  \
# 0  BAGUA GRANDE                    AV. CHACHAPOYAS 2044  BAGUA GRANDE
# 1      CHIMBOTE  AV. FRANCISCO BOLOGNESI 696 - CHIMBOTE      CHIMBOTE
#
#    provincia departamento
# 0  UTCUBAMBA     AMAZONAS
# 1      SANTA       ANCASH

# %%
#we keep only LIMA observations
bbva_peru["departamento"].replace(["LIMA.1"], ["LIMA"], inplace =   True)
print(bbva_peru['departamento'].value_counts())
df = bbva_peru.loc[bbva_peru["departamento"] == "LIMA", :]
# Out:
# LIMA             206
# AREQUIPA          12
# LA LIBERTAD       12
# PIURA             10
# JUNIN              9
# LAMBAYEQUE         7
# SAN MARTIN         6
# CUSCO              6
# ICA                5
# ANCASH             5
# LORETO             4
# CAJAMARCA          4
# PUNO               3
# UCAYALI            3
# HUANUCO            3
# MOQUEGUA           2
# APURIMAC           2
# TACNA              2
# MADRE DE DIOS      1
# PASCO.1            1
# AYACUCHO           1
# TUMBES             1
# AMAZONAS           1
# Name: departamento, dtype: int64

# %%
#concatenate the district and the direction of the bank to help the searcher
cols = ['direccion', 'distrito']
df[ 'complete_address' ] = df[ cols ].apply(lambda row: ', '.\
                                  join( row.values.astype( str ) ) , axis = 1 )
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10772\3454748180.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[ 'complete_address' ] = df[ cols ].apply(lambda row: ', '.\

# %%
df['direc'] = df['complete_address'] + " " + "BBVA"
df.head(5)
#By adding strings from "DISTRITO", there is more information in the adress and we reduce the NANs from 39 to 7.
#Then, by adding "BBVA" to the string we reduce the missing values from 6 to 3.
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10772\4274332164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['direc'] = df['complete_address'] + " " + "BBVA"
#              oficina                                          direccion  \
# 78       CAMINO REAL                                AV. CAMINO REAL 355
# 79       28 DE JULIO                                AV. 28 DE JULIO 775
# 80  ABANCAY-CONGRESO                                AV. ABANCAY 260-262
# 81        AEROPUERTO       CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A
# 82      ANGAMOS ESTE  Av. Angamos Este 215 - 227, esquina con Av. Pe...
#
#       distrito provincia departamento  \
# 78  SAN ISIDRO      LIMA         LIMA
# 79        LIMA      LIMA         LIMA
# 80        LIMA      LIMA         LIMA
# 81      CALLAO      LIMA         LIMA
# 82  MIRAFLORES      LIMA         LIMA
#
#                                      complete_address  \
# 78                    AV. CAMINO REAL 355, SAN ISIDRO
# 79                          AV. 28 DE JULIO 775, LIMA
# 80                          AV. ABANCAY 260-262, LIMA
# 81  CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A, ...
# 82  Av. Angamos Este 215 - 227, esquina con Av. Pe...
#
#                                                 direc
# 78               AV. CAMINO REAL 355, SAN ISIDRO BBVA
# 79                     AV. 28 DE JULIO 775, LIMA BBVA
# 80                     AV. ABANCAY 260-262, LIMA BBVA
# 81  CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A, ...
# 82  Av. Angamos Este 215 - 227, esquina con Av. Pe...

# %% [markdown]
# ## 2. Then we find the coordinates for each BBVA office

# %% [markdown]
# Use GoogleMaps API and geocode all the BBVA offices. For those offices that Google API gets no information, use internet and get the latitude and longitude handly and add them to dataset.

# %%
coord = np.zeros(shape=( len(df.direc), 2), dtype =float)
i=0

# %%
gmaps = googlemaps.Client(key='AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g')

# Loop over lists
for d in tqdm(df.direc):   

    # Geocoding an address
    geocode_result = gmaps.geocode( d , region = 'pe')
    
    # Check the len of result
    if len(geocode_result)==0 :
        coord[i][0] = np.nan
        coord[i][1] = np.nan

    
    # Get info
    else :
        coord[i][0] = geocode_result[0]['geometry']['location']['lat']
        coord[i][1] = geocode_result[0]['geometry']['location']['lng']
        
    i=i+1
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10772\1261474639.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for d in tqdm(df.direc):
#   0%|          | 0/206 [00:00<?, ?it/s]

# %%
#Create the dataframe with the new coordenates
coords = pd.DataFrame( coord.tolist() , columns = ["Lat", "Lon"] )
coords['direc'] = df.direc
coords
# Out:
#            Lat        Lon                                              direc
# 0   -12.097362 -77.036099                                                NaN
# 1   -12.064030 -77.037961                                                NaN
# 2   -12.047955 -77.026997                                                NaN
# 3   -12.023538 -77.104397                                                NaN
# 4   -12.113476 -77.028582                                                NaN
# ..         ...        ...                                                ...
# 201 -12.062448 -77.093581  AV. AVIACIÓN 3328, MZ. B1 LT. 6, URB. LAS MAGN...
# 202 -12.062026 -77.092444                AV. IGNACIO MERINO 2099, LINCE BBVA
# 203 -12.038676 -76.976219  AV. PRIMAVERA 2180-2190, ESQ. CON AV. CENTRAL ...
# 204 -11.994069 -77.063041                                                NaN
# 205 -11.963811 -77.063462            ALFREDO MENDIOLA 3685., LOS OLIVOS BBVA
#
# [206 rows x 3 columns]

# %%
#Now we merge the coordenates dataframe with the original dataframe into the final df
df_final = df.merge(coords, left_on='direc', right_on='direc', how='left')
df_final.drop('direc', inplace=True, axis=1)
df_final.index.name = 'id'
df_final.reset_index(inplace=True)
df_final
# Out:
#       id                 oficina  \
# 0      0             CAMINO REAL
# 1      1             28 DE JULIO
# 2      2        ABANCAY-CONGRESO
# 3      3              AEROPUERTO
# 4      4            ANGAMOS ESTE
# ..   ...                     ...
# 201  201     NESTLE-DONOFRIO 164
# 202  202  BIENESTAR DE LA MARINA
# 203  203                 SEDAPAL
# 204  204         ESPECIAL SENATI
# 205  205          VILLA INFANTAS
#
#                                              direccion       distrito  \
# 0                                  AV. CAMINO REAL 355     SAN ISIDRO
# 1                                  AV. 28 DE JULIO 775           LIMA
# 2                                  AV. ABANCAY 260-262           LIMA
# 3         CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A         CALLAO
# 4    Av. Angamos Este 215 - 227, esquina con Av. Pe...     MIRAFLORES
# ..                                                 ...            ...
# 201                                 AV. VENEZUELA 2580           LIMA
# 202                          AV. VENEZUELA S/N CDRA 34     SAN MIGUEL
# 203  KM. 1 AUTOPISTA RAMIRO PRIALE (AL INTERIOR DE ...    EL AGUSTINO
# 204                          AV. ALFREDO MENDIOLA 3520  INDEPENDENCIA
# 205  MZ. K, SUB LOTE 4A, PARCELA A-1. LOTIZACIÓN IN...     LOS OLIVOS
#
#     provincia departamento                                   complete_address  \
# 0        LIMA         LIMA                    AV. CAMINO REAL 355, SAN ISIDRO
# 1        LIMA         LIMA                          AV. 28 DE JULIO 775, LIMA
# 2        LIMA         LIMA                          AV. ABANCAY 260-262, LIMA
# 3        LIMA         LIMA  CENTRO AÉREO COMERCIAL LOCALES 110 A Y 111 A, ...
# 4        LIMA         LIMA  Av. Angamos Este 215 - 227, esquina con Av. Pe...
# ..        ...          ...                                                ...
# 201      LIMA         LIMA                           AV. VENEZUELA 2580, LIMA
# 202      LIMA         LIMA              AV. VENEZUELA S/N CDRA 34, SAN MIGUEL
# 203      LIMA         LIMA  KM. 1 AUTOPISTA RAMIRO PRIALE (AL INTERIOR DE ...
# 204      LIMA         LIMA           AV. ALFREDO MENDIOLA 3520, INDEPENDENCIA
# 205      LIMA         LIMA  MZ. K, SUB LOTE 4A, PARCELA A-1. LOTIZACIÓN IN...
#
#            Lat        Lon
# 0   -12.067611 -77.115078
# 1   -12.055685 -77.096612
# 2   -11.107431 -77.608089
# 3   -11.496517 -77.211773
# 4   -12.016421 -76.825004
# ..         ...        ...
# 201        NaN        NaN
# 202        NaN        NaN
# 203        NaN        NaN
# 204        NaN        NaN
# 205        NaN        NaN
#
# [206 rows x 9 columns]

# %% [markdown]
# ### Now we replace NAs by hand

# %%
isnan = df_final[df_final.isna().any(axis=1)]
len(isnan)
#There are 3 cases with missing values: Mala, Naciones Unidas & Strip Center Barranca
# Out:
# 101

# %%
isnan
# Out:
#       id                 oficina  \
# 33    33                 CAMACHO
# 45    45      CC. REAL PLAZA PRO
# 79    79         HIPOLITO UNANUE
# 92    92               LA MARINA
# 109  109              LOS ROBLES
# ..   ...                     ...
# 201  201     NESTLE-DONOFRIO 164
# 202  202  BIENESTAR DE LA MARINA
# 203  203                 SEDAPAL
# 204  204         ESPECIAL SENATI
# 205  205          VILLA INFANTAS
#
#                                              direccion              distrito  \
# 33                    AV. PROL. JAVIER PRADO ESTE 4921             LA MOLINA
# 45             AV. ALFREDO MENDIOLA 7038-7042, LC B-02  SAN MARTIN DE PORRES
# 79                  JR HIPOLITO UNANUE 1616-1620, LC 3           LA VICTORIA
# 92   AV. LA MARINA N° 2355 CENTRO COMERCIAL LA MARI...            SAN MIGUEL
# 109                               AV. DOS DE MAYO 1198            SAN ISIDRO
# ..                                                 ...                   ...
# 201                                 AV. VENEZUELA 2580                  LIMA
# 202                          AV. VENEZUELA S/N CDRA 34            SAN MIGUEL
# 203  KM. 1 AUTOPISTA RAMIRO PRIALE (AL INTERIOR DE ...           EL AGUSTINO
# 204                          AV. ALFREDO MENDIOLA 3520         INDEPENDENCIA
# 205  MZ. K, SUB LOTE 4A, PARCELA A-1. LOTIZACIÓN IN...            LOS OLIVOS
#
#     provincia departamento                                   complete_address  \
# 33       LIMA         LIMA        AV. PROL. JAVIER PRADO ESTE 4921, LA MOLINA
# 45       LIMA         LIMA  AV. ALFREDO MENDIOLA 7038-7042, LC B-02, SAN M...
# 79       LIMA         LIMA    JR HIPOLITO UNANUE 1616-1620, LC 3, LA VICTORIA
# 92       LIMA         LIMA  AV. LA MARINA N° 2355 CENTRO COMERCIAL LA MARI...
# 109      LIMA         LIMA                   AV. DOS DE MAYO 1198, SAN ISIDRO
# ..        ...          ...                                                ...
# 201      LIMA         LIMA                           AV. VENEZUELA 2580, LIMA
# 202      LIMA         LIMA              AV. VENEZUELA S/N CDRA 34, SAN MIGUEL
# 203      LIMA         LIMA  KM. 1 AUTOPISTA RAMIRO PRIALE (AL INTERIOR DE ...
# 204      LIMA         LIMA           AV. ALFREDO MENDIOLA 3520, INDEPENDENCIA
# 205      LIMA         LIMA  MZ. K, SUB LOTE 4A, PARCELA A-1. LOTIZACIÓN IN...
#
#      Lat  Lon
# 33   NaN  NaN
# 45   NaN  NaN
# 79   NaN  NaN
# 92   NaN  NaN
# 109  NaN  NaN
# ..   ...  ...
# 201  NaN  NaN
# 202  NaN  NaN
# 203  NaN  NaN
# 204  NaN  NaN
# 205  NaN  NaN
#
# [101 rows x 9 columns]

# %%
#Oficina Mala
df_final.loc[113,'Lat']= -12.6558538
df_final.loc[113,'Lon']= -76.6348772
#Oficina Naciones Unidas
df_final.loc[127,'Lat']= -12.1003510
df_final.loc[127,'Lon']= -77.0636233
#Oficina Strip Center Barranca
df_final.loc[40,'Lat']= -10.75237060
df_final.loc[40,'Lon']= -77.75986317

# %% [markdown]
# ## 3. Find driving time

# %% [markdown]
# Use Google API to find the driving time (best guess) from all the group members' address and all the LIMA BBVA offices.

# %% [markdown]
# Les puse direcciones al azar. Sería cuestión que lo editen.

# %% [markdown]
# #### Group members' address
# - Alejandro: -12.1148761,-77.0386600
# - Steph: -12.1148389,-77.0117565
# - Juan Carlos: -12.0961813,-77.0714548
# - Gabriela: -12.0259368,-77.0069487

# %%
#We subset only coordenates and transform them to strings instead of floats
bbva = df_final.iloc[:, [7,8]].applymap(str)
bbva.head(2)
# Out:
#            Lat          Lon
# 0  -12.0676108  -77.1150782
# 1  -12.0556849  -77.0966119

# %%
#Create a list of "destinations"
bbva['destino'] = bbva['Lat'] + "," + bbva['Lon']
destino = bbva['destino'].tolist()
destino
# Out:
# ['-12.0676108,-77.1150782',
#  '-12.0556849,-77.0966119',
#  '-11.1074314,-77.6080894',
#  '-11.4965172,-77.21177329999999',
#  '-12.016421,-76.8250038',
#  '-12.0279109,-77.0575418',
#  '-11.9916265,-77.07262639999999',
#  '-12.0317332,-77.0712543',
#  '-12.0738899,-77.0489924',
#  '-12.0851775,-76.97939810000001',
#  '-12.094951,-77.03747',
#  '-12.0496302,-77.0375281',
#  '-12.1012422,-76.9706199',
#  '-12.1111508,-76.9873252',
#  '-12.0775066,-77.0870468',
#  '-12.0678936,-76.9584569',
#  '-12.0598246,-77.1351292',
#  '-12.077758,-76.91851199999999',
#  '-13.5295906,-71.96458539999999',
#  '-12.0737038,-76.9560571',
#  '-12.0619569,-77.02961669999999',
#  '-12.1235885,-77.02911619999999',
#  '-12.0922232,-77.0236816',
#  '-12.007389,-77.0054625',
#  '-12.0518113,-77.03360909999999',
#  '-12.0379707,-77.0986351',
#  '-12.1037833,-77.001634',
#  '-12.0852949,-77.03225119999999',
#  '-12.1053898,-76.9654438',
#  '-11.976987,-77.067587',
#  '-12.0917418,-77.04293109999999',
#  '-12.0982554,-76.9625544',
#  '-12.0922212,-77.0716281',
#  'nan,nan',
#  '-12.0565632,-77.1015012',
#  '-12.0566677,-76.97018369999999',
#  '-12.1512936,-76.9817363',
#  '-12.0779212,-77.0924843',
#  '-12.0433031,-76.97036729999999',
#  '-11.9933447,-77.0630175',
#  '-10.7523706,-77.75986317',
#  '-12.048302,-77.10948069999999',
#  '-12.1298821,-77.02995059999999',
#  '-12.1119042,-76.9905617',
#  '-11.9900851,-77.0623155',
#  'nan,nan',
#  '-12.083724,-77.014596',
#  '-12.0731638,-77.00545989999999',
#  '-12.0963256,-77.059482',
#  '-12.0675511,-77.097178',
#  '-12.1188312,-77.0318743',
#  '-12.1010005,-77.01074489999999',
#  '-12.0218001,-77.0596169',
#  '-12.0776021,-77.0863292',
#  '-12.1192591,-77.03667899999999',
#  '-12.0736141,-77.0164831',
#  '-12.0867852,-77.04302659999999',
#  '-12.130877,-76.9836123',
#  '-12.052213,-77.0250164',
#  '-12.1295446,-77.001098',
#  '-12.1436671,-77.01548609999999',
#  '-11.1094613,-77.61369479999999',
#  '-12.0130189,-77.0835114',
#  '-12.0825241,-77.0506498',
#  '-12.0427179,-77.0427897',
#  '-11.9388104,-77.0721461',
#  '-11.8605174,-77.0798698',
#  '-12.0107549,-76.87354859999999',
#  '-12.0463731,-77.042754',
#  '-12.0898612,-77.05266859999999',
#  '-12.1192904,-77.0268905',
#  '-12.0823232,-76.92840249999999',
#  '-12.0762692,-76.9872565',
#  '-12.0995207,-77.0564507',
#  '-12.025525,-77.03315549999999',
#  '-12.0897789,-77.0030872',
#  '-12.0954443,-76.9947088',
#  '-11.9009721,-77.0403492',
#  '-12.0939282,-77.0211518',
#  'nan,nan',
#  '-12.0873282,-76.99597589999999',
#  '-12.0315637,-77.0693201',
#  '-12.0482495,-77.0590644',
#  '-12.1094516,-77.0357456',
#  '-12.1028926,-77.0526646',
#  '-12.0687172,-77.0302241',
#  '-12.0640616,-76.9605648',
#  '-12.163,-76.99091',
#  '-12.1073943,-77.01579079999999',
#  '-11.9988068,-77.0626908',
#  '-12.0814037,-77.08250559999999',
#  '-11.944697,-77.028683',
#  'nan,nan',
#  '-12.1239426,-76.9841302',
#  '-12.0546784,-77.0429695',
#  '-12.0558083,-77.0588649',
#  '-11.8453779,-77.1426224',
#  '-12.1660988,-76.95210949999999',
#  '-12.1849604,-77.0066252',
#  '-12.0260034,-76.9008717',
#  '-12.0273078,-77.00736080000001',
#  '-10.7525374,-77.7599218',
#  '-12.0972997,-77.0360668',
#  '-12.1416088,-76.9918155',
#  '-12.104926,-76.9707944',
#  '-12.0624481,-77.0935808',
#  '-12.0620255,-77.0924442',
#  '-12.0386756,-76.976219',
#  '-11.9638112,-77.063462',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  '-12.6558538,-76.6348772',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  '-12.100351,-77.0636233',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan',
#  'nan,nan']

# %%
#Alejandro
df_driving = pd.DataFrame (destino, columns = ['destination'])
df_driving['origin'] = "-12.1148761,-77.0386600"
df_driving
# Out:
#                         destination                   origin
# 0           -12.0676108,-77.1150782  -12.1148761,-77.0386600
# 1           -12.0556849,-77.0966119  -12.1148761,-77.0386600
# 2           -11.1074314,-77.6080894  -12.1148761,-77.0386600
# 3    -11.4965172,-77.21177329999999  -12.1148761,-77.0386600
# 4            -12.016421,-76.8250038  -12.1148761,-77.0386600
# ..                              ...                      ...
# 201                         nan,nan  -12.1148761,-77.0386600
# 202                         nan,nan  -12.1148761,-77.0386600
# 203                         nan,nan  -12.1148761,-77.0386600
# 204                         nan,nan  -12.1148761,-77.0386600
# 205                         nan,nan  -12.1148761,-77.0386600
#
# [206 rows x 2 columns]

# %%
#Steph
df_driving2 = pd.DataFrame (destino, columns = ['destination'])
df_driving2['origin'] = "-12.1148389,-77.0117565"
df_driving2
# Out:
#                         destination                   origin
# 0           -12.0676108,-77.1150782  -12.1148389,-77.0117565
# 1           -12.0556849,-77.0966119  -12.1148389,-77.0117565
# 2           -11.1074314,-77.6080894  -12.1148389,-77.0117565
# 3    -11.4965172,-77.21177329999999  -12.1148389,-77.0117565
# 4            -12.016421,-76.8250038  -12.1148389,-77.0117565
# ..                              ...                      ...
# 201                         nan,nan  -12.1148389,-77.0117565
# 202                         nan,nan  -12.1148389,-77.0117565
# 203                         nan,nan  -12.1148389,-77.0117565
# 204                         nan,nan  -12.1148389,-77.0117565
# 205                         nan,nan  -12.1148389,-77.0117565
#
# [206 rows x 2 columns]

# %%
#Gabriela
df_driving3 = pd.DataFrame (destino, columns = ['destination'])
df_driving3['origin'] = "-12.0259368,-77.0069487"
df_driving3
# Out:
#                         destination                   origin
# 0           -12.0676108,-77.1150782  -12.0259368,-77.0069487
# 1           -12.0556849,-77.0966119  -12.0259368,-77.0069487
# 2           -11.1074314,-77.6080894  -12.0259368,-77.0069487
# 3    -11.4965172,-77.21177329999999  -12.0259368,-77.0069487
# 4            -12.016421,-76.8250038  -12.0259368,-77.0069487
# ..                              ...                      ...
# 201                         nan,nan  -12.0259368,-77.0069487
# 202                         nan,nan  -12.0259368,-77.0069487
# 203                         nan,nan  -12.0259368,-77.0069487
# 204                         nan,nan  -12.0259368,-77.0069487
# 205                         nan,nan  -12.0259368,-77.0069487
#
# [206 rows x 2 columns]

# %%
#Juan Carlos
df_driving4 = pd.DataFrame (destino, columns = ['destination'])
df_driving4['origin'] = "-12.0961813,-77.0714548"
df_driving4
# Out:
#                         destination                   origin
# 0           -12.0676108,-77.1150782  -12.0961813,-77.0714548
# 1           -12.0556849,-77.0966119  -12.0961813,-77.0714548
# 2           -11.1074314,-77.6080894  -12.0961813,-77.0714548
# 3    -11.4965172,-77.21177329999999  -12.0961813,-77.0714548
# 4            -12.016421,-76.8250038  -12.0961813,-77.0714548
# ..                              ...                      ...
# 201                         nan,nan  -12.0961813,-77.0714548
# 202                         nan,nan  -12.0961813,-77.0714548
# 203                         nan,nan  -12.0961813,-77.0714548
# 204                         nan,nan  -12.0961813,-77.0714548
# 205                         nan,nan  -12.0961813,-77.0714548
#
# [206 rows x 2 columns]

# %%
df_driving_final = pd.concat([df_driving, df_driving2, df_driving3, df_driving4]).reset_index(drop=True)
df_driving_final
# Out:
#                         destination                   origin
# 0           -12.0676108,-77.1150782  -12.1148761,-77.0386600
# 1           -12.0556849,-77.0966119  -12.1148761,-77.0386600
# 2           -11.1074314,-77.6080894  -12.1148761,-77.0386600
# 3    -11.4965172,-77.21177329999999  -12.1148761,-77.0386600
# 4            -12.016421,-76.8250038  -12.1148761,-77.0386600
# ..                              ...                      ...
# 819                         nan,nan  -12.0961813,-77.0714548
# 820                         nan,nan  -12.0961813,-77.0714548
# 821                         nan,nan  -12.0961813,-77.0714548
# 822                         nan,nan  -12.0961813,-77.0714548
# 823                         nan,nan  -12.0961813,-77.0714548
#
# [824 rows x 2 columns]

# %%
df_driving_final['combination'] = list(range(1,len(df_driving_final)+1))
df_driving_final
# Out:
#                         destination                   origin  combination
# 0           -12.0676108,-77.1150782  -12.1148761,-77.0386600            1
# 1           -12.0556849,-77.0966119  -12.1148761,-77.0386600            2
# 2           -11.1074314,-77.6080894  -12.1148761,-77.0386600            3
# 3    -11.4965172,-77.21177329999999  -12.1148761,-77.0386600            4
# 4            -12.016421,-76.8250038  -12.1148761,-77.0386600            5
# ..                              ...                      ...          ...
# 819                         nan,nan  -12.0961813,-77.0714548          820
# 820                         nan,nan  -12.0961813,-77.0714548          821
# 821                         nan,nan  -12.0961813,-77.0714548          822
# 822                         nan,nan  -12.0961813,-77.0714548          823
# 823                         nan,nan  -12.0961813,-77.0714548          824
#
# [824 rows x 3 columns]

# %%
#Create the three lists: combination, origin and destination
combination = df_driving_final['combination'].tolist()
origin = df_driving_final['origin'].tolist()
destination = df_driving_final['destination'].tolist()

# %%
data_distance = {}

# %%
# Loop to generate info about geolocations
duration_info = np.zeros(shape=(len(combination),2), dtype =float)
i=0

for c,o,d in tqdm(list(zip(combination, origin, destination))):
    try:
        # Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

    ## Fixed Parameters
        # Paramaters
        traffic_model = 'best_guess'  

        # Departure time
        departure_time = 'now'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = 'AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g'

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region = 'pe'

     ## Parameters
        # Origin
        origin = o
        
        # Destinations
        destination = d
        
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        
        # Concatenate strings
        request = endpoint + nav_request
        print(request)

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()
        
        

        #Loads response as JSON
        directions = json.loads(response)

        legs = directions['routes'][0]['legs'][0]
        #print(legs)
        
        duration_info[i][0] = c
        duration_info[i][1] = legs['duration']['value']
        #print(duration_info[i][1])
        
        i=i+1

        my_keys = ['duration']
        info = { my_key: legs[my_key] for my_key in my_keys }
        data_distance[c] = info 
    
    except Exception as e:
        
        duration_info[i][0] = c
        duration_info[i][1] = "nan"
        
        i=i+1
        
        print(c)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10772\680288981.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combination, origin, destination))):
#   0%|          | 0/824 [00:00<?, ?it/s]
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0676108,-77.1150782&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0556849,-77.0966119&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-11.1074314,-77.6080894&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-11.4965172,-77.21177329999999&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.016421,-76.8250038&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0279109,-77.0575418&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-11.9916265,-77.07262639999999&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0317332,-77.0712543&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0738899,-77.0489924&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0851775,-76.97939810000001&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.094951,-77.03747&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0496302,-77.0375281&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.1012422,-76.9706199&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.1111508,-76.9873252&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0775066,-77.0870468&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0678936,-76.9584569&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0598246,-77.1351292&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.077758,-76.91851199999999&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-13.5295906,-71.96458539999999&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0737038,-76.9560571&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0619569,-77.02961669999999&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.1235885,-77.02911619999999&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0922232,-77.0236816&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.007389,-77.0054625&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0518113,-77.03360909999999&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.0379707,-77.0986351&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.1148761,-77.0386600&destination=-12.
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 736
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 737
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 738
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 739
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 740
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 741
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 742
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 743
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 744
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 745
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=-12.100351,-77.0636233&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 747
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 748
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 749
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 750
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 751
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 752
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 753
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 754
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 755
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 756
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 757
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 758
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 759
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 760
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 761
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 762
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 763
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 764
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 765
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 766
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 767
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 768
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 769
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 770
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 771
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 772
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 773
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 774
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 775
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 776
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 777
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 778
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 779
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 780
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 781
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 782
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 783
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 784
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 785
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 786
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 787
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 788
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 789
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 790
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 791
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 792
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 793
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 794
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 795
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 796
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g
# 797
# https://maps.googleapis.com/maps/api/directions/json?origin=-12.0961813,-77.0714548&destination=nan,nan&departure_time=now&traffic_model=best_guess&mode=driving&region=pe&key=AIzaSyD5CNJfBkf_OIH_D4shwz_Bz8MRgoJBe_g

# %%
duration_info

# %%
distance_api = pd.DataFrame(duration_info, columns = ['Combination', 'Duration_seg'])
distance_api

# %% [markdown]
# ## 4. Report offices closets and furthest from each group members' adress

# %% [markdown]
# Se me ocurre que podríamos crear un dataframe en base a lo anterior (cuando se arregle) que sea una columna por miembro del grupo con el tiempo a cada una de las 205 oficinas, y hacemos un merge con la df_final. Luego que nos dé la fila donde está el valor mínimo y máximo para cada una de las 4 columnas y así identificamos las oficinas.

# %%
group_size = 206  # Set group size to 206
num_groups = (len(distance_api) - 1) // group_size + 1  # Calculate number of groups needed
distance_api['group'] = [i // group_size + 1 for i in range(len(distance_api))]  # Assign group numbers

# %%
distance_api

# %%
#Alejandro
distance_api_1 = distance_api[distance_api["group"] == 1]
distance_api_1.sort_values(by=['Duration_seg'])

# %% [markdown]
# The BBVAs closest to Alejandro's house are those belonging to the combination with the 175, 139 and 56 BBVA in the list. While the farthest are those belonging to the combination with the 149, 93 and 159 BBVA in the list. The nearest is the Plaza Union office, and the fartest is the Santa Monica office.

# %%
df_list = df[(df.index == 175) | (df.index == 149)]
df_list

# %%
#Steph
distance_api_2 = distance_api[distance_api["group"] == 2]
distance_api_2.sort_values(by=['Duration_seg'])

# %% [markdown]
# The BBVAs closest to Stephy's house are those belonging to the combination with the 24, 7 and 21 BBVA in the list (229, 212 and 226). While the farthest are those belonging to the combination with the 150, 94 and 160 BBVA in the list (355, 299 and 365). The nearest is the C.C Fiori office and the fartest is the Parque Industrial in Villa El Salvador office.

# %%
df_list_2 = df[(df.index == 24) | (df.index == 150)]
df_list_2

# %%
#Gabriela
distance_api_2 = distance_api[distance_api["group"] == 3]
distance_api_2.sort_values(by=['Duration_seg'])

# %% [markdown]
# The BBVAs closest to Gabriela's house are those belonging to the combination with the 130, 116 and 88  BBVAs of the lista (540, 526 and 498), while the farthest are those belonging to the combination with 151, 95 and 191 BBVA of the list (561, 505 and 571).The nearest is the Nicolas Ayllon office and the fartest is the Pro office.

# %%
df_list_3 = df[(df.index == 130) | (df.index == 151)]
df_list_3

# %%
#JC
distance_api_4 = distance_api[distance_api["group"] == 4]
distance_api_4.sort_values(by=['Duration_seg'])

# %% [markdown]
# The BBVAs closest to Juan Carlos' house are those belonging to the combination with the 131, 116 and 89 BBVAs of the list (746, 731 and 704). While the farthest are those belonging to the combination with the 162, 96 and 152 BBVA of the list (777, 711 and 767). The nearest is the Orrantia office and the fartest is the Samuel del Alcalzar office.

# %%
df_list_4 = df[(df.index == 131) | (df.index == 162)]
df_list_4
