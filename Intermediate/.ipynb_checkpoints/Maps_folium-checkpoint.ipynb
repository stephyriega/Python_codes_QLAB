# %% [markdown]
# ### 1 Import the data located at this link ("https://github.com/alexanderquispe/Diplomado_PUCP/raw/main/_data/institutos1.csv"). It has information on Tech Institutes' total vacancies, total applicants, total entrants, and total enrolled. Moreover, the institutes are geolocated.

# %% [markdown]
# Use this shapefile to generate a Choropleth map of the total institutes' vacancies by the department. Use the overlay function (link and JN) to intersect institutes dataset with shapefiles

# %%
import pandas as pd

data = pd.read_csv("https://github.com/alexanderquispe/Diplomado_PUCP/raw/main/_data/institutos1.csv")
data.head(3)
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
# 2   239970                    537                              1047
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
# 2                     484                      476  0.886406  1.949721  -61
#
#    dif1   nlat_ie  ...  population_ccpp  altitude  Dblock1km  Dblock2km  \
# 0   174 -13.52107  ...         106400.0    3386.0   14840369     742184
# 1   262 -13.63997  ...          45864.0    2342.0   14970470     748235
# 2   510 -15.47827  ...         216716.0    3831.0   17000163     850081
#
#    Dblock3km  Dblock5km  Dblock10km  Dblock20km  Dblock30km       _merge
# 0     494123     296073      148036        7418        4912  matched (3)
# 1     499156     299094      149047        7423        4915  matched (3)
# 2     566054     340032      170016        8508        5605  matched (3)
#
# [3 rows x 21 columns]

# %%
data.shape
# Out:
# (215, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   cod_mod                           215 non-null    int64
#  1   ltimoden_metaatencion             215 non-null    int64
#  2   cuentadeid_postulante_procesoadm  215 non-null    int64
#  3   sumaden_flagingresante            215 non-null    int64
#  4   sumaden_flagmatriculado           215 non-null    int64
#  5   ratio                             215 non-null    float64
#  6   ratio1                            215 non-null    float64
#  7   dif                               215 non-null    int64
#  8   dif1                              215 non-null    int64
#  9   nlat_ie                           215 non-null    float64
#  10  nlong_ie                          215 non-null    float64
#  11  population_ccpp                   194 non-null    float64
#  12  altitude                          194 non-null    float64
#  13  Dblock1km                         215 non-null    int64
#  14  Dblock2km                         215 non-null    int64
#  15  Dblock3km                         215 non-null    int64
#  16  Dblock5km                         215 non-null    int64
#  17  Dblock10km                        215 non-null    int64
#  18  Dblock20km                        215 non-null    int64
#  19  Dblock30km                        215 non-null    int64
#  20  _merge                            215 non-null    object
# dtypes: float64(6), int64(14), object(1)
# memory usage: 35.4+ KB

# %%
data.isna().sum()
# Out:
# cod_mod                              0
# ltimoden_metaatencion                0
# cuentadeid_postulante_procesoadm     0
# sumaden_flagingresante               0
# sumaden_flagmatriculado              0
# ratio                                0
# ratio1                               0
# dif                                  0
# dif1                                 0
# nlat_ie                              0
# nlong_ie                             0
# population_ccpp                     21
# altitude                            21
# Dblock1km                            0
# Dblock2km                            0
# Dblock3km                            0
# Dblock5km                            0
# Dblock10km                           0
# Dblock20km                           0
# Dblock30km                           0
# _merge                               0
# dtype: int64

# %%
import geopandas as gpd

# %%
data_geo = gpd.GeoDataFrame(data, crs =  "EPSG:4326", 
                            geometry=gpd.points_from_xy(data.nlong_ie,data.nlat_ie))

path_shape = "../_data/INEI_LIMITE_DEPARTAMENTAL/INEI_LIMITE_DEPARTAMENTAL.shp"
shape_department = gpd.read_file(path_shape)

intersection_data_geo = gpd.overlay(data_geo,shape_department,how="intersection")

vars_sum=["ltimoden_metaatencion","cuentadeid_postulante_procesoadm","sumaden_flagingresante",
          "sumaden_flagmatriculado"]

total_department = intersection_data_geo.groupby(["CCDD"],as_index="False")[vars_sum].sum()

total_department_shape = shape_department.merge(total_department, on= "CCDD")

# %%
data_geo.head(2)
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
#
#    dif1   nlat_ie  ...  altitude  Dblock1km  Dblock2km  Dblock3km  Dblock5km  \
# 0   174 -13.52107  ...    3386.0   14840369     742184     494123     296073
# 1   262 -13.63997  ...    2342.0   14970470     748235     499156     299094
#
#    Dblock10km  Dblock20km  Dblock30km       _merge  \
# 0      148036        7418        4912  matched (3)
# 1      149047        7423        4915  matched (3)
#
#                       geometry
# 0  POINT (-71.97748 -13.52107)
# 1  POINT (-72.88261 -13.63997)
#
# [2 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 10))

total_department_shape.plot(column='ltimoden_metaatencion', cmap='OrRd', ax=ax, legend=True, legend_kwds={'label': 'Total Vacancies'})

# set the title and axis labels
ax.set_title('Number of Vacancys by Department')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# add color for NA values
ax.set_facecolor('lightgrey')

# %% [markdown]
# ### 2. Make an interactive map of markes using visual_html function and show total vacancies, applicants, entrants, and enrolled information in a table popup. Additionally, use "university" as icon.
# Take this map as an example

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      -------------------------------------- 102.3/102.3 kB 2.9 MB/s eta 0:00:00
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sriega\appdata\local\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
import folium
from folium.plugins import MarkerCluster

# create map centered on Peru
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

# create marker cluster
marker_cluster = MarkerCluster().add_to(mapa)

# define function to create html table popup (the info inside the pop-up)
def create_popup_table(row):
    html = '<table style="width:100%">' \
           '<tr><td><b>Total vacancies:</b></td><td>{}</td></tr>' \
           '<tr><td><b>Total applicants:</b></td><td>{}</td></tr>' \
           '<tr><td><b>Total entrants:</b></td><td>{}</td></tr>' \
           '<tr><td><b>Total enrolled:</b></td><td>{}</td></tr>' \
           '</table>'.format(row['ltimoden_metaatencion'],
                              row['cuentadeid_postulante_procesoadm'],
                              row['sumaden_flagingresante'],
                              row['sumaden_flagmatriculado'])
    return folium.Popup(html, max_width=500)

# loop through data and add markers to map
for i, row in data.iterrows():
    folium.Marker(location=[row['geometry'].y, row['geometry'].x],
                  popup=create_popup_table(row),
                  icon=folium.Icon(icon='university', prefix='fa')).add_to(marker_cluster)
    
# ajusta el zoom del mapa a los límites de los marcadores
mapa.fit_bounds(mapa.get_bounds())

# display map
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8e0b2883475bc7fc81e706fc703fbf6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8e0b2883475bc7fc81e706fc703fbf6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8e0b2883475bc7fc81e706fc703fbf6 = L.map(
#                 &quot;map_f8e0b2883475bc7fc81e706fc703fbf6&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ad3cc7434c964eceec90470adb2a399 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f8e0b2883475bc7fc81e706fc703fbf6);
#
#
#             var marker_cluster_c615baf53066365b13605c21de6ee68a = L.markerClusterGroup(
#                 {}
#             );
#             map_f8e0b2883475bc7fc81e706fc703fbf6.addLayer(marker_cluster_c615baf53066365b13605c21de6ee68a);
#
#
#             var marker_e010397e60f89333d37f15e23c44a396 = L.marker(
#                 [-13.52107, -71.97748],
#                 {}
#             ).addTo(marker_cluster_c615baf53066365b13605c21de6ee68a);
#
#
#             var icon_7b101cdfed3b9b09c28a343ddb1b1c78 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e010397e60f89333d37f15e23c44a396.setIcon(icon_7b101cdfed3b9b09c28a343ddb1b1c78);
#
#
#         var popup_c75d13a8488a1eeb4fd7c8006e4be475 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_1abd4c6b84245911203e19796fdc93bc = $(`&lt;div id=&quot;html_1abd4c6b84245911203e19796fdc93bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table style=&quot;width:100%&quot;&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total vacancies:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;307&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total applicants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;481&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total entrants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;302&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total enrolled:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;301&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_c75d13a8488a1eeb4fd7c8006e4be475.setContent(html_1abd4c6b84245911203e19796fdc93bc);
#
#
#
#         marker_e010397e60f89333d37f15e23c44a396.bindPopup(popup_c75d13a8488a1eeb4fd7c8006e4be475)
#         ;
#
#
#
#
#             var marker_3a46077ee9916c7fae8f75a1f45f800d = L.marker(
#                 [-13.63997, -72.88261],
#                 {}
#             ).addTo(marker_cluster_c615baf53066365b13605c21de6ee68a);
#
#
#             var icon_8d7367570765e216161bf8ae3d93df87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3a46077ee9916c7fae8f75a1f45f800d.setIcon(icon_8d7367570765e216161bf8ae3d93df87);
#
#
#         var popup_c25fc9fd025c1f4bd158642debd9cc2b = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_9168f6415c65b105d53c3612de447bd7 = $(`&lt;div id=&quot;html_9168f6415c65b105d53c3612de447bd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table style=&quot;width:100%&quot;&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total vacancies:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;240&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total applicants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;502&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total entrants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;204&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total enrolled:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;204&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_c25fc9fd025c1f4bd158642debd9cc2b.setContent(html_9168f6415c65b105d53c3612de447bd7);
#
#
#
#         marker_3a46077ee9916c7fae8f75a1f45f800d.bindPopup(popup_c25fc9fd025c1f4bd158642debd9cc2b)
#         ;
#
#
#
#
#             var marker_7e420ff15fc4c78494b6be5

# %% [markdown]
# ### 3. Generate the ratio of applicants by vacancies and store it in a new columns called ratio_applicants_vacancies ( total applicants / total vacancies ). Then, generate a cluster map with two groups of marker clusters. The first group should be compound by those institutes where there were more applicants than vacancies. Name this group as Applicant Surplus. The second group should be compound by those institutes where there were more vacancies than applicants. Name this group as Applicant Deficit.

# %%
data['ratio_applicants_vacancies'] = data['cuentadeid_postulante_procesoadm'] / data['ltimoden_metaatencion']

# %%
# crea un mapa centrado en Perú
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

# crea dos grupos de marcadores para Applicant Surplus y Applicant Deficit
applicant_surplus_cluster = MarkerCluster(name='Applicant Surplus').add_to(mapa)
applicant_deficit_cluster = MarkerCluster(name='Applicant Deficit').add_to(mapa)

# itera sobre los datos y agrega marcadores a cada grupo de marcadores según el ratio de postulantes por vacantes
for i, row in data.iterrows():
    ratio = row['ratio_applicants_vacancies']
    location = [row['geometry'].y, row['geometry'].x]
    popup = create_popup_table(row)
    if ratio > 1:  # si hay más postulantes que vacantes
        icon = folium.Icon(color='red', icon='university', prefix='fa')
        folium.Marker(location=location, popup=popup, icon=icon).add_to(applicant_surplus_cluster)
    else:  # si hay más vacantes que postulantes
        icon = folium.Icon(color='green', icon='university', prefix='fa')
        folium.Marker(location=location, popup=popup, icon=icon).add_to(applicant_deficit_cluster)

# agrega un controlador de capas al mapa para alternar entre Applicant Surplus y Applicant Deficit
folium.LayerControl().add_to(mapa)


# muestra el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_530eb955404a349aab3e87df784b4131 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_530eb955404a349aab3e87df784b4131&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_530eb955404a349aab3e87df784b4131 = L.map(
#                 &quot;map_530eb955404a349aab3e87df784b4131&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a38c50eac071062b71fead9be9e265fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_530eb955404a349aab3e87df784b4131);
#
#
#             var marker_cluster_177d2ba95527cfd03f5cca889b6d813f = L.markerClusterGroup(
#                 {}
#             );
#             map_530eb955404a349aab3e87df784b4131.addLayer(marker_cluster_177d2ba95527cfd03f5cca889b6d813f);
#
#
#             var marker_7a8fd531624ae7d0df292af8db269c02 = L.marker(
#                 [-13.52107, -71.97748],
#                 {}
#             ).addTo(marker_cluster_177d2ba95527cfd03f5cca889b6d813f);
#
#
#             var icon_bc69a68d26750e7b11fe89d2dc36c5e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7a8fd531624ae7d0df292af8db269c02.setIcon(icon_bc69a68d26750e7b11fe89d2dc36c5e2);
#
#
#         var popup_5b08c39b275208b26d444d26695d9783 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_e43ac7b9e8e9fe226fde3372d9405749 = $(`&lt;div id=&quot;html_e43ac7b9e8e9fe226fde3372d9405749&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table style=&quot;width:100%&quot;&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total vacancies:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;307&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total applicants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;481&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total entrants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;302&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total enrolled:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;301&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_5b08c39b275208b26d444d26695d9783.setContent(html_e43ac7b9e8e9fe226fde3372d9405749);
#
#
#
#         marker_7a8fd531624ae7d0df292af8db269c02.bindPopup(popup_5b08c39b275208b26d444d26695d9783)
#         ;
#
#
#
#
#             var marker_9900df5921892ebb8f6e4229abdce2ba = L.marker(
#                 [-13.63997, -72.88261],
#                 {}
#             ).addTo(marker_cluster_177d2ba95527cfd03f5cca889b6d813f);
#
#
#             var icon_1be44893b7361caa5c1af7975992b5d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9900df5921892ebb8f6e4229abdce2ba.setIcon(icon_1be44893b7361caa5c1af7975992b5d1);
#
#
#         var popup_bc4b3c17a92bab7ce1dfe1a423084e08 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_f471f2730c3bd88eb8670a5f407813b7 = $(`&lt;div id=&quot;html_f471f2730c3bd88eb8670a5f407813b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table style=&quot;width:100%&quot;&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total vacancies:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;240&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total applicants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;502&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total entrants:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;204&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td&gt;&lt;b&gt;Total enrolled:&lt;/b&gt;&lt;/td&gt;&lt;td&gt;204&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_bc4b3c17a92bab7ce1dfe1a423084e08.setContent(html_f471f2730c3bd88eb8670a5f407813b7);
#
#
#
#         marker_9900df5921892ebb8f6e4229abdce2ba.bindPopup(popup_bc4b3c17a92bab7ce1dfe1a423084e08)
#         ;
#
#
#
#
#             var marker_f05e8f9a08b47835a8bfd8d77

# %% [markdown]
# ### 4 Generate a Circle map and plot only institutes with more applicants than vacancies. Make the radius= ratio_applicants_vacancies * 10000 . Make these circles of color green. Name the layer of circles as Applicant Surplus. Use FeatureGroup

# %%
data2 = data[data['ratio_applicants_vacancies']>1]
data2.head(2)
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 0   207597                    307                               481
# 1   207613                    240                               502
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 0                     302                      301  0.980456  1.566775   -6
# 1                     204                      204  0.850000  2.091667  -36
#
#    dif1   nlat_ie  ...  Dblock1km  Dblock2km  Dblock3km  Dblock5km  \
# 0   174 -13.52107  ...   14840369     742184     494123     296073
# 1   262 -13.63997  ...   14970470     748235     499156     299094
#
#    Dblock10km  Dblock20km  Dblock30km       _merge  \
# 0      148036        7418        4912  matched (3)
# 1      149047        7423        4915  matched (3)
#
#                       geometry  ratio_applicants_vacancies
# 0  POINT (-71.97748 -13.52107)                    1.566775
# 1  POINT (-72.88261 -13.63997)                    2.091667
#
# [2 rows x 23 columns]

# %%
# crea un mapa centrado en Perú
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

ap_s = folium.FeatureGroup(name='Applicant Surplus', control=True)

for _, row in data2.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="#4da170",
                  color="#4da170").add_to(ap_s)

ap_s.add_to(mapa)  # add the feature group to the map

folium.LayerControl().add_to(mapa)  # add layer control to the map

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_929d8d35bcea50267dac1e278559d366 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_929d8d35bcea50267dac1e278559d366&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_929d8d35bcea50267dac1e278559d366 = L.map(
#                 &quot;map_929d8d35bcea50267dac1e278559d366&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_472c6c5b162ba40d12a58a8c4f4a7bfe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_929d8d35bcea50267dac1e278559d366);
#
#
#             var feature_group_f30e83f2eac0324611d9d880da920908 = L.featureGroup(
#                 {}
#             ).addTo(map_929d8d35bcea50267dac1e278559d366);
#
#
#             var circle_6b737c8bd79a42d7031c69f4d956723c = L.circle(
#                 [-13.52107, -71.97748],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15667.752442996743, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_f30e83f2eac0324611d9d880da920908);
#
#
#             var circle_622d251561dcd06f15825ee060893934 = L.circle(
#                 [-13.63997, -72.88261],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20916.666666666668, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_f30e83f2eac0324611d9d880da920908);
#
#
#             var circle_cb7741442cd69ded060f2051e4f1d9ba = L.circle(
#                 [-15.47827, -70.12756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19497.206703910615, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_f30e83f2eac0324611d9d880da920908);
#
#
#             var circle_7e2cbd67e576fcce4ece36e3d4285e80 = L.circle(
#                 [-6.23041, -77.86943],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12434.988179669032, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_f30e83f2eac0324611d9d880da920908);
#
#
#             var circle_3d146981d8e9d3b31d392ca0c38b2e39 = L.circle(
#                 [-6.49004, -76.36539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12800.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_f30e83f2eac0324611d9d880da920908);
#
#
#             var circle_298f255a27638f9fb876dac950686f09 = L.circle(
#                 [-9.9344, -76.2369],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &

# %% [markdown]
# ### 5 Generate a Circle map and plot only institutes with less applicants than vacancies. Make the radius= ratio_applicants_vacancies * 10000 . Make these circles of color red. Name the layer of circles as Applicant Deficit. Use FeatureGroup.

# %%
data3 = data[data['ratio_applicants_vacancies']<1]
data3.head(2)
# Out:
#    cod_mod  ltimoden_metaatencion  cuentadeid_postulante_procesoadm  \
# 5   276188                    570                               461
# 8   356972                    480                               430
#
#    sumaden_flagingresante  sumaden_flagmatriculado     ratio    ratio1  dif  \
# 5                     426                      406  0.712281  0.808772 -164
# 8                     316                      316  0.658333  0.895833 -164
#
#    dif1   nlat_ie  ...  Dblock1km  Dblock2km  Dblock3km  Dblock5km  \
# 5  -109 -14.05115  ...   15430789     771394     514263     308157
# 8   -50  -5.18106  ...    5621336     281668     187445     112267
#
#    Dblock10km  Dblock20km  Dblock30km       _merge  \
# 5      154078        7739        5126  matched (3)
# 8       56133        2866        1844  matched (3)
#
#                       geometry  ratio_applicants_vacancies
# 5  POINT (-75.75387 -14.05115)                    0.808772
# 8   POINT (-80.66289 -5.18106)                    0.895833
#
# [2 rows x 23 columns]

# %%
# crea un mapa centrado en Perú
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

ap_d = folium.FeatureGroup(name='Applicant Deficit', control=True)

for _, row in data3.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="#d62f41",
                  color="#d62f41").add_to(ap_d)

ap_d.add_to(mapa)  # add the feature group to the map

folium.LayerControl().add_to(mapa)  # add layer control to the map

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae87e80c5cdbfaf954e96afa290e4329 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae87e80c5cdbfaf954e96afa290e4329&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae87e80c5cdbfaf954e96afa290e4329 = L.map(
#                 &quot;map_ae87e80c5cdbfaf954e96afa290e4329&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5cbcf45a2e03b48c22a50130aacab1d1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ae87e80c5cdbfaf954e96afa290e4329);
#
#
#             var feature_group_82e0e1e3211f3f1ff278b3746136b300 = L.featureGroup(
#                 {}
#             ).addTo(map_ae87e80c5cdbfaf954e96afa290e4329);
#
#
#             var circle_6bac293456d8c28088a1c4940ca295c3 = L.circle(
#                 [-14.05115, -75.75387],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d62f41&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d62f41&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8087.719298245614, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_82e0e1e3211f3f1ff278b3746136b300);
#
#
#             var circle_da1f7734d2ddb11714fa4938ad4c7f50 = L.circle(
#                 [-5.18106, -80.66289],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d62f41&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d62f41&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8958.333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_82e0e1e3211f3f1ff278b3746136b300);
#
#
#             var circle_725ef3f593c639a5925c27a95fb90037 = L.circle(
#                 [-11.2539, -74.637],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d62f41&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d62f41&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6222.222222222223, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_82e0e1e3211f3f1ff278b3746136b300);
#
#
#             var circle_77407ac259b7b402fe840419177e2e2e = L.circle(
#                 [-12.04935, -77.03284],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d62f41&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d62f41&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1576.283441793203, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_82e0e1e3211f3f1ff278b3746136b300);
#
#
#             var circle_58190e3d17280f9973e9f02b0134d7c0 = L.circle(
#                 [-11.38346, -75.68851],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d62f41&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d62f41&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9980.079681274901, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_82e0e1e3211f3f1ff278b3746136b300);
#
#
#             var circle_5f3d736f755c431766913c2f167e4be3 = L.circle(
#                 [-7.9025, -78.5657],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d62f41&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d62f41&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.

# %% [markdown]
# ### 6. Generate a Circle Map that combines map 4 and 5 into a unique map. Use FeatureGroup. Additionally, generate a legend for this map indicating the color and label.

# %%
import branca

# crea un mapa centrado en Perú
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)

ap_s = folium.FeatureGroup(name='Applicant Surplus', control=True)
ap_d = folium.FeatureGroup(name='Applicant Deficit', control=True)

#applicant surplus
for _, row in data2.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="#4da170",
                  color="#4da170").add_to(ap_s)
    
# applicant deficit
mapa = folium.Map(location=[-9.189967, -75.015152], zoom_start=6)
for _, row in data3.iterrows():
    
    folium.Circle(location=[row['geometry'].y, row['geometry'].x],
                  radius=row['ratio_applicants_vacancies'] * 10000,
                  fill=True,
                  fill_color="#d62f41",
                  color="#d62f41").add_to(ap_d)

ap_s.add_to(mapa)  # add the feature group to the map
ap_d.add_to(mapa)  # add the feature group to the map

folium.LayerControl().add_to(mapa)  # add layer control to the map
mapa


legend_html_0 = '''
<div style="
position: fixed; 
bottom: 10px;
left: 10px;
width: 200px;
height: 120px;
z-index:9999;
font-size:14px;
<p><a style="color:black;font-size:100%;margin-left:5px;">&#9658;</a>&emsp;<b>Legend</b></p>
<p><a style="color:green;font-size:100%;margin-left:5px;">&#9679;</a>&emsp;<b>Applicant Surplus</b></p>
<p><a style="color:red;font-size:100%;margin-left:5px;">&#9679;</a>&emsp;<b>Applicant Deficit</b></p>



</div>
<div style="
position: fixed; 
bottom: 10px;
left: 10px;
width: 200px;
height: 120px; 
z-index:9998;
font-size:14px;
background-color: #ffffff;

opacity: 0.7;
">
</div>
'''

# Add legend
legend_html = "{% macro html(this, kwargs) %}" + legend_html_0 + "{% endmacro %}"
legend = branca.element.MacroElement()
legend._template = branca.element.Template(legend_html)
mapa.get_root().add_child(legend)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b79adae9893e57c64d318e028d184f06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b79adae9893e57c64d318e028d184f06&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;
# position: fixed;
# bottom: 10px;
# left: 10px;
# width: 200px;
# height: 120px;
# z-index:9999;
# font-size:14px;
# &lt;p&gt;&lt;a style=&quot;color:black;font-size:100%;margin-left:5px;&quot;&gt;&amp;#9658;&lt;/a&gt;&amp;emsp;&lt;b&gt;Legend&lt;/b&gt;&lt;/p&gt;
# &lt;p&gt;&lt;a style=&quot;color:green;font-size:100%;margin-left:5px;&quot;&gt;&amp;#9679;&lt;/a&gt;&amp;emsp;&lt;b&gt;Applicant Surplus&lt;/b&gt;&lt;/p&gt;
# &lt;p&gt;&lt;a style=&quot;color:red;font-size:100%;margin-left:5px;&quot;&gt;&amp;#9679;&lt;/a&gt;&amp;emsp;&lt;b&gt;Applicant Deficit&lt;/b&gt;&lt;/p&gt;
#
#
#
# &lt;/div&gt;
# &lt;div style=&quot;
# position: fixed;
# bottom: 10px;
# left: 10px;
# width: 200px;
# height: 120px;
# z-index:9998;
# font-size:14px;
# background-color: #ffffff;
#
# opacity: 0.7;
# &quot;&gt;
# &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b79adae9893e57c64d318e028d184f06 = L.map(
#                 &quot;map_b79adae9893e57c64d318e028d184f06&quot;,
#                 {
#                     center: [-9.189967, -75.015152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d4767d6312fd062b5e5044ab71eec92 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b79adae9893e57c64d318e028d184f06);
#
#
#             var feature_group_a3ef490beb864b73ed056c8d7eac45b1 = L.featureGroup(
#                 {}
#             ).addTo(map_b79adae9893e57c64d318e028d184f06);
#
#
#             var circle_81271e412527b01d5eda094386bf014c = L.circle(
#                 [-13.52107, -71.97748],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15667.752442996743, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a3ef490beb864b73ed056c8d7eac45b1);
#
#
#             var circle_08a92605c833a6ffff1ac82840421dd3 = L.circle(
#                 [-13.63997, -72.88261],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20916.666666666668, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a3ef490beb864b73ed056c8d7eac45b1);
#
#
#             var circle_36bd2e49fcbba557505e0710c7b2828d = L.circle(
#                 [-15.47827, -70.12756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19497.206703910615, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a3ef490beb864b73ed056c8d7eac45b1);
#
#
#             var circle_bf70c7a024ade2276096e6dabf1779fd = L.circle(
#                 [-6.23041, -77.86943],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12434.988179669032, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a3ef490beb864b73ed056c8d7eac45b1);
#
#
#             var circle_2d340917ffffd3517a59083a6d725ea8 = L.circle(
#                 [-6.49004, -76.36539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4da170&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#4da170&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &
